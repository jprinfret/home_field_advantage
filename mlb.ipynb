# %% [markdown]
# # Evaluating Home Field Advantage During the 2018 Regular NFL Season

# %% [markdown]
# ## Import needed packages and config

# %%
import requests
import mysql.connector
import config
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to MySql  and create database. Commented out once DB is created

# %%
cnx = mysql.connector.connect(
        host = config.host,
        user = config.user,
        password = config.password,
)
cursor = cnx.cursor(buffered=True)

# %% [markdown]
# ## (re)Connect to database, with database defined, to create table

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = 'sports'
)
cursor = cnx.cursor(buffered=True)

# %% [markdown]
# ## Make API Call to grab 2019 MLB reg season data

# %%
api_key = config.mlb_key
headers = {'Ocp-Apim-Subscription-Key' : '{}'.format(api_key)}

# %%
mlb_data = []
url = 'https://api.sportsdata.io/v3/mlb/scores/json/Games/2019'
response = requests.get(url, headers=headers)
data = response.json()
mlb_data.append(data)

# %%
mlb_data = mlb_data[0] # data came back as list of lists of dictionaries.

# %%
mlb_data
# Out:
# [{'GameID': 54052,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-20T00:00:00',
#   'DateTime': '2019-03-20T05:35:00',
#   'AwayTeam': 'SEA',
#   'HomeTeam': 'OAK',
#   'AwayTeamID': 13,
#   'HomeTeamID': 24,
#   'RescheduledGameID': None,
#   'StadiumID': 69,
#   'Channel': 'ESPN',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 14,
#   'HomeTeamRuns': 11,
#   'AwayTeamHits': 11,
#   'HomeTeamHits': 14,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10003325,
#   'LosingPitcherID': 10000694,
#   'SavingPitcherID': 10001121,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10003325,
#   'HomeTeamProbablePitcherID': 10000694,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10003325,
#   'HomeTeamStartingPitcherID': 10000694,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 14.4,
#   'AwayTeamMoneyLine': 231,
#   'HomeTeamMoneyLine': -250,
#   'ForecastTempLow': 88,
#   'ForecastTempHigh': 101,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 101,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 386,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054052,
#   'GlobalAwayTeamID': 10000013,
#   'GlobalHomeTeamID': 10000024,
#   'PointSpreadAwayTeamMoneyLine': -263,
#   'PointSpreadHomeTeamMoneyLine': 237,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-03-20T22:20:03',
#   'GameEndDateTime': '2019-03-20T09:02:27',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54066,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-21T00:00:00',
#   'DateTime': '2019-03-21T05:35:00',
#   'AwayTeam': 'SEA',
#   'HomeTeam': 'OAK',
#   'AwayTeamID': 13,
#   'HomeTeamID': 24,
#   'RescheduledGameID': None,
#   'StadiumID': 69,
#   'Channel': 'ESPN',
#   'Inning': 12,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 13,
#   'HomeTeamRuns': 10,
#   'AwayTeamHits': 14,
#   'HomeTeamHits': 16,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000200,
#   'LosingPitcherID': 10001515,
#   'SavingPitcherID': 10001121,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10009612,
#   'HomeTeamProbablePitcherID': 10001290,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10009612,
#   'HomeTeamStartingPitcherID': 10001290,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 15.2,
#   'AwayTeamMoneyLine': -189,
#   'HomeTeamMoneyLine': 175,
#   'ForecastTempLow': 109,
#   'ForecastTempHigh': 117,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 117,
#   'ForecastWindSpeed': 8,
#   'ForecastWindDirection': 535,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054066,
#   'GlobalAwayTeamID': 10000013,
#   'GlobalHomeTeamID': 10000024,
#   'PointSpreadAwayTeamMoneyLine': -372,
#   'PointSpreadHomeTeamMoneyLine': 332,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-03-21T22:20:12',
#   'GameEndDateTime': '2019-03-21T10:04:26',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54155,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T13:05:00',
#   'AwayTeam': 'BAL',
#   'HomeTeam': 'NYY',
#   'AwayTeamID': 19,
#   'HomeTeamID': 29,
#   'RescheduledGameID': None,
#   'StadiumID': 35,
#   'Channel': 'ESPN,YES,MASN2',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 5,
#   'HomeTeamRuns': 11,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 14,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 3,
#   'WinningPitcherID': 10000850,
#   'LosingPitcherID': 10001017,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001017,
#   'HomeTeamProbablePitcherID': 10000850,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001017,
#   'HomeTeamStartingPitcherID': 10000850,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 13.6,
#   'AwayTeamMoneyLine': 540,
#   'HomeTeamMoneyLine': -625,
#   'ForecastTempLow': 72,
#   'ForecastTempHigh': 74,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 66,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 314,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054155,
#   'GlobalAwayTeamID': 10000019,
#   'GlobalHomeTeamID': 10000029,
#   'PointSpreadAwayTeamMoneyLine': 258,
#   'PointSpreadHomeTeamMoneyLine': -301,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:28',
#   'GameEndDateTime': '2019-03-28T16:20:52',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54156,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T13:05:00',
#   'AwayTeam': 'NYM',
#   'HomeTeam': 'WSH',
#   'AwayTeamID': 18,
#   'HomeTeamID': 35,
#   'RescheduledGameID': None,
#   'StadiumID': 53,
#   'Channel': 'SNY,MASN',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 5,
#   'HomeTeamRuns': 0,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 13,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000787,
#   'LosingPitcherID': 10000426,
#   'SavingPitcherID': 10005753,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000787,
#   'HomeTeamProbablePitcherID': 10000426,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000787,
#   'HomeTeamStartingPitcherID': 10000426,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 10.4,
#   'AwayTeamMoneyLine': 172,
#   'HomeTeamMoneyLine': -186,
#   'ForecastTempLow': 79,
#   'ForecastTempHigh': 83,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 72,
#   'ForecastWindSpeed': 14,
#   'ForecastWindDirection': 324,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054156,
#   'GlobalAwayTeamID': 10000018,
#   'GlobalHomeTeamID': 10000035,
#   'PointSpreadAwayTeamMoneyLine': -330,
#   'PointSpreadHomeTeamMoneyLine': 295,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:30',
#   'GameEndDateTime': '2019-03-28T15:53:40',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54157,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T14:10:00',
#   'AwayTeam': 'STL',
#   'HomeTeam': 'MIL',
#   'AwayTeamID': 31,
#   'HomeTeamID': 32,
#   'RescheduledGameID': None,
#   'StadiumID': 19,
#   'Channel': 'FSMW,FSWI',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 10,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000371,
#   'LosingPitcherID': 10001250,
#   'SavingPitcherID': 10006039,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001250,
#   'HomeTeamProbablePitcherID': 10000371,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001250,
#   'HomeTeamStartingPitcherID': 10000371,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 14.4,
#   'AwayTeamMoneyLine': 172,
#   'HomeTeamMoneyLine': -184,
#   'ForecastTempLow': 59,
#   'ForecastTempHigh': 67,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 51,
#   'ForecastWindSpeed': 11,
#   'ForecastWindDirection': 515,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054157,
#   'GlobalAwayTeamID': 10000031,
#   'GlobalHomeTeamID': 10000032,
#   'PointSpreadAwayTeamMoneyLine': -305,
#   'PointSpreadHomeTeamMoneyLine': 274,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:33',
#   'GameEndDateTime': '2019-03-28T16:51:04',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54158,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T15:05:00',
#   'AwayTeam': 'ATL',
#   'HomeTeam': 'PHI',
#   'AwayTeamID': 26,
#   'HomeTeamID': 12,
#   'RescheduledGameID': None,
#   'StadiumID': 51,
#   'Channel': 'WCAU,FSSE',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 10,
#   'HomeTeamRuns': 16,
#   'AwayTeamHits': 11,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 5,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10005232,
#   'LosingPitcherID': 10000066,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000066,
#   'HomeTeamProbablePitcherID': 10005232,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000066,
#   'HomeTeamStartingPitcherID': 10005232,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 12.8,
#   'AwayTeamMoneyLine': 260,
#   'HomeTeamMoneyLine': -289,
#   'ForecastTempLow': 72,
#   'ForecastTempHigh': 77,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 67,
#   'ForecastWindSpeed': 15,
#   'ForecastWindDirection': 311,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054158,
#   'GlobalAwayTeamID': 10000026,
#   'GlobalHomeTeamID': 10000012,
#   'PointSpreadAwayTeamMoneyLine': -208,
#   'PointSpreadHomeTeamMoneyLine': 176,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:35',
#   'GameEndDateTime': '2019-03-28T18:14:14',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54159,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T15:37:00',
#   'AwayTeam': 'DET',
#   'HomeTeam': 'TOR',
#   'AwayTeamID': 17,
#   'HomeTeamID': 3,
#   'RescheduledGameID': None,
#   'StadiumID': 42,
#   'Channel': 'FSD,RSN',
#   'Inning': 10,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 5,
#   'HomeTeamRuns': 0,
#   'AwayTeamHits': 10,
#   'HomeTeamHits': 5,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10005346,
#   'LosingPitcherID': 10000014,
#   'SavingPitcherID': 10000414,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001353,
#   'HomeTeamProbablePitcherID': 10001305,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001353,
#   'HomeTeamStartingPitcherID': 10001305,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 14.4,
#   'AwayTeamMoneyLine': 210,
#   'HomeTeamMoneyLine': -232,
#   'ForecastTempLow': 67,
#   'ForecastTempHigh': 75,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 67,
#   'ForecastWindSpeed': 14,
#   'ForecastWindDirection': 409,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054159,
#   'GlobalAwayTeamID': 10000017,
#   'GlobalHomeTeamID': 10000003,
#   'PointSpreadAwayTeamMoneyLine': -244,
#   'PointSpreadHomeTeamMoneyLine': 213,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:38',
#   'GameEndDateTime': '2019-03-28T18:35:41',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54154,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:00:00',
#   'AwayTeam': 'HOU',
#   'HomeTeam': 'TB',
#   'AwayTeamID': 30,
#   'HomeTeamID': 11,
#   'RescheduledGameID': None,
#   'StadiumID': 18,
#   'Channel': 'ATSW,SUN',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 13,
#   'HomeTeamRuns': 3,
#   'AwayTeamHits': 16,
#   'HomeTeamHits': 10,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000432,
#   'LosingPitcherID': 10005315,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000432,
#   'HomeTeamProbablePitcherID': 10005315,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000432,
#   'HomeTeamStartingPitcherID': 10005315,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': -208,
#   'HomeTeamMoneyLine': 180,
#   'ForecastTempLow': 104,
#   'ForecastTempHigh': 112,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 104,
#   'ForecastWindSpeed': 27,
#   'ForecastWindDirection': 85,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054154,
#   'GlobalAwayTeamID': 10000030,
#   'GlobalHomeTeamID': 10000011,
#   'PointSpreadAwayTeamMoneyLine': 213,
#   'PointSpreadHomeTeamMoneyLine': -260,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:40',
#   'GameEndDateTime': '2019-03-28T18:40:37',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54153,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:05:00',
#   'AwayTeam': 'CHC',
#   'HomeTeam': 'TEX',
#   'AwayTeamID': 9,
#   'HomeTeamID': 28,
#   'RescheduledGameID': None,
#   'StadiumID': 21,
#   'Channel': 'WGN,FSSW',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 19,
#   'HomeTeamRuns': 10,
#   'AwayTeamHits': 21,
#   'HomeTeamHits': 15,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000193,
#   'LosingPitcherID': 10000060,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000193,
#   'HomeTeamProbablePitcherID': 10000060,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000193,
#   'HomeTeamStartingPitcherID': 10000060,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 15.2,
#   'AwayTeamMoneyLine': -184,
#   'HomeTeamMoneyLine': 160,
#   'ForecastTempLow': 109,
#   'ForecastTempHigh': 115,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 109,
#   'ForecastWindSpeed': 29,
#   'ForecastWindDirection': 281,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054153,
#   'GlobalAwayTeamID': 10000009,
#   'GlobalHomeTeamID': 10000028,
#   'PointSpreadAwayTeamMoneyLine': 205,
#   'PointSpreadHomeTeamMoneyLine': -240,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:43',
#   'GameEndDateTime': '2019-03-28T19:18:34',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54161,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:07:00',
#   'AwayTeam': 'LAA',
#   'HomeTeam': 'OAK',
#   'AwayTeamID': 21,
#   'HomeTeamID': 24,
#   'RescheduledGameID': None,
#   'StadiumID': 23,
#   'Channel': 'CSCA,FSW',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 0,
#   'HomeTeamRuns': 10,
#   'AwayTeamHits': 8,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 3,
#   'WinningPitcherID': 10000694,
#   'LosingPitcherID': 10000004,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000004,
#   'HomeTeamProbablePitcherID': 10000694,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000004,
#   'HomeTeamStartingPitcherID': 10000694,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 14.4,
#   'AwayTeamMoneyLine': -176,
#   'HomeTeamMoneyLine': -167,
#   'ForecastTempLow': 83,
#   'ForecastTempHigh': 85,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 83,
#   'ForecastWindSpeed': 11,
#   'ForecastWindDirection': 425,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054161,
#   'GlobalAwayTeamID': 10000021,
#   'GlobalHomeTeamID': 10000024,
#   'PointSpreadAwayTeamMoneyLine': -353,
#   'PointSpreadHomeTeamMoneyLine': 298,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:45',
#   'GameEndDateTime': '2019-03-28T18:31:31',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54163,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:10:00',
#   'AwayTeam': 'PIT',
#   'HomeTeam': 'CIN',
#   'AwayTeamID': 4,
#   'HomeTeamID': 2,
#   'RescheduledGameID': None,
#   'StadiumID': 64,
#   'Channel': 'ATPT,FSOH',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 8,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 15,
#   'AwayTeamErrors': 5,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000234,
#   'LosingPitcherID': 10000986,
#   'SavingPitcherID': 10000013,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000986,
#   'HomeTeamProbablePitcherID': 10007245,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000986,
#   'HomeTeamStartingPitcherID': 10007245,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 13.6,
#   'AwayTeamMoneyLine': -165,
#   'HomeTeamMoneyLine': -184,
#   'ForecastTempLow': 91,
#   'ForecastTempHigh': 93,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 93,
#   'ForecastWindSpeed': 15,
#   'ForecastWindDirection': 349,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054163,
#   'GlobalAwayTeamID': 10000004,
#   'GlobalHomeTeamID': 10000002,
#   'PointSpreadAwayTeamMoneyLine': -329,
#   'PointSpreadHomeTeamMoneyLine': 281,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:48',
#   'GameEndDateTime': '2019-03-28T19:07:48',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54160,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:10:00',
#   'AwayTeam': 'ARI',
#   'HomeTeam': 'LAD',
#   'AwayTeamID': 14,
#   'HomeTeamID': 1,
#   'RescheduledGameID': None,
#   'StadiumID': 31,
#   'Channel': 'ESPN,FSAZ,SNLA',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 13,
#   'HomeTeamRuns': 19,
#   'AwayTeamHits': 14,
#   'HomeTeamHits': 19,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000628,
#   'LosingPitcherID': 10000613,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000613,
#   'HomeTeamProbablePitcherID': 10000628,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000613,
#   'HomeTeamStartingPitcherID': 10000628,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': 232,
#   'HomeTeamMoneyLine': -268,
#   'ForecastTempLow': 82,
#   'ForecastTempHigh': 85,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 82,
#   'ForecastWindSpeed': 5,
#   'ForecastWindDirection': 337,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054160,
#   'GlobalAwayTeamID': 10000014,
#   'GlobalHomeTeamID': 10000001,
#   'PointSpreadAwayTeamMoneyLine': -252,
#   'PointSpreadHomeTeamMoneyLine': 216,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:50',
#   'GameEndDateTime': '2019-03-28T19:03:36',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54165,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:10:00',
#   'AwayTeam': 'COL',
#   'HomeTeam': 'MIA',
#   'AwayTeamID': 23,
#   'HomeTeamID': 22,
#   'RescheduledGameID': None,
#   'StadiumID': 57,
#   'Channel': 'ATRM,FSFL',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 15,
#   'HomeTeamRuns': 8,
#   'AwayTeamHits': 14,
#   'HomeTeamHits': 10,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 5,
#   'WinningPitcherID': 10005835,
#   'LosingPitcherID': 10003284,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10005835,
#   'HomeTeamProbablePitcherID': 10003284,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10005835,
#   'HomeTeamStartingPitcherID': 10003284,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 12.0,
#   'AwayTeamMoneyLine': -226,
#   'HomeTeamMoneyLine': 197,
#   'ForecastTempLow': 111,
#   'ForecastTempHigh': 114,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 111,
#   'ForecastWindSpeed': 26,
#   'ForecastWindDirection': 61,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054165,
#   'GlobalAwayTeamID': 10000023,
#   'GlobalHomeTeamID': 10000022,
#   'PointSpreadAwayTeamMoneyLine': 197,
#   'PointSpreadHomeTeamMoneyLine': -226,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:52',
#   'GameEndDateTime': '2019-03-28T19:09:23',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54162,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:10:00',
#   'AwayTeam': 'CLE',
#   'HomeTeam': 'MIN',
#   'AwayTeamID': 10,
#   'HomeTeamID': 20,
#   'RescheduledGameID': None,
#   'StadiumID': 14,
#   'Channel': 'FSNO,STO',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 0,
#   'HomeTeamRuns': 5,
#   'AwayTeamHits': 5,
#   'HomeTeamHits': 10,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10001993,
#   'LosingPitcherID': 10000335,
#   'SavingPitcherID': 10001952,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000335,
#   'HomeTeamProbablePitcherID': 10001993,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000335,
#   'HomeTeamStartingPitcherID': 10001993,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 12.0,
#   'AwayTeamMoneyLine': 168,
#   'HomeTeamMoneyLine': -194,
#   'ForecastTempLow': 51,
#   'ForecastTempHigh': 55,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 38,
#   'ForecastWindSpeed': 16,
#   'ForecastWindDirection': 564,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054162,
#   'GlobalAwayTeamID': 10000010,
#   'GlobalHomeTeamID': 10000020,
#   'PointSpreadAwayTeamMoneyLine': 273,
#   'PointSpreadHomeTeamMoneyLine': -321,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:54',
#   'GameEndDateTime': '2019-03-28T18:37:03',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54164,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:10:00',
#   'AwayTeam': 'SF',
#   'HomeTeam': 'SD',
#   'AwayTeamID': 15,
#   'HomeTeamID': 33,
#   'RescheduledGameID': None,
#   'StadiumID': 1,
#   'Channel': 'FSSD,CSBA',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 0,
#   'HomeTeamRuns': 5,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 15,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10007041,
#   'LosingPitcherID': 10001105,
#   'SavingPitcherID': 10001208,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001105,
#   'HomeTeamProbablePitcherID': 10007041,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001105,
#   'HomeTeamStartingPitcherID': 10007041,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 12.0,
#   'AwayTeamMoneyLine': 188,
#   'HomeTeamMoneyLine': -218,
#   'ForecastTempLow': 75,
#   'ForecastTempHigh': 80,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 72,
#   'ForecastWindSpeed': 10,
#   'ForecastWindDirection': 450,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054164,
#   'GlobalAwayTeamID': 10000015,
#   'GlobalHomeTeamID': 10000033,
#   'PointSpreadAwayTeamMoneyLine': -298,
#   'PointSpreadHomeTeamMoneyLine': 248,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:57',
#   'GameEndDateTime': '2019-03-28T18:32:34',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54152,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T16:15:00',
#   'AwayTeam': 'CHW',
#   'HomeTeam': 'KC',
#   'AwayTeamID': 16,
#   'HomeTeamID': 5,
#   'RescheduledGameID': None,
#   'StadiumID': 33,
#   'Channel': 'CSCh,FSKC',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 8,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 10,
#   'HomeTeamHits': 13,
#   'AwayTeamErrors': 8,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10005970,
#   'LosingPitcherID': 10002099,
#   'SavingPitcherID': 10001190,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10002099,
#   'HomeTeamProbablePitcherID': 10005970,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10002099,
#   'HomeTeamStartingPitcherID': 10005970,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 13.6,
#   'AwayTeamMoneyLine': 176,
#   'HomeTeamMoneyLine': -191,
#   'ForecastTempLow': 88,
#   'ForecastTempHigh': 104,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 88,
#   'ForecastWindSpeed': 14,
#   'ForecastWindDirection': 329,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054152,
#   'GlobalAwayTeamID': 10000016,
#   'GlobalHomeTeamID': 10000005,
#   'PointSpreadAwayTeamMoneyLine': -306,
#   'PointSpreadHomeTeamMoneyLine': 274,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:31:59',
#   'GameEndDateTime': '2019-03-28T21:15:52',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54166,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-28T00:00:00',
#   'DateTime': '2019-03-28T19:08:00',
#   'AwayTeam': 'BOS',
#   'HomeTeam': 'SEA',
#   'AwayTeamID': 25,
#   'HomeTeamID': 13,
#   'RescheduledGameID': None,
#   'StadiumID': 65,
#   'Channel': 'ESPN',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 10,
#   'HomeTeamRuns': 19,
#   'AwayTeamHits': 18,
#   'HomeTeamHits': 19,
#   'AwayTeamErrors': 5,
#   'HomeTeamErrors': 5,
#   'WinningPitcherID': 10003325,
#   'LosingPitcherID': 10000249,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000249,
#   'HomeTeamProbablePitcherID': 10003325,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000249,
#   'HomeTeamStartingPitcherID': 10003325,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': -329,
#   'HomeTeamMoneyLine': 281,
#   'ForecastTempLow': 82,
#   'ForecastTempHigh': 82,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 82,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 563,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054166,
#   'GlobalAwayTeamID': 10000025,
#   'GlobalHomeTeamID': 10000013,
#   'PointSpreadAwayTeamMoneyLine': -188,
#   'PointSpreadHomeTeamMoneyLine': 164,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-03-28T22:52:16',
#   'GameEndDateTime': '2019-03-28T22:47:08',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54169,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T19:07:00',
#   'AwayTeam': 'DET',
#   'HomeTeam': 'TOR',
#   'AwayTeamID': 17,
#   'HomeTeamID': 3,
#   'RescheduledGameID': None,
#   'StadiumID': 42,
#   'Channel': 'FSD,RSN',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 0,
#   'HomeTeamRuns': 15,
#   'AwayTeamHits': 5,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000568,
#   'LosingPitcherID': 10004421,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10004421,
#   'HomeTeamProbablePitcherID': 10000568,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10004421,
#   'HomeTeamStartingPitcherID': 10000568,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 14.4,
#   'AwayTeamMoneyLine': 181,
#   'HomeTeamMoneyLine': -199,
#   'ForecastTempLow': 55,
#   'ForecastTempHigh': 59,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 55,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 147,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054169,
#   'GlobalAwayTeamID': 10000017,
#   'GlobalHomeTeamID': 10000003,
#   'PointSpreadAwayTeamMoneyLine': -289,
#   'PointSpreadHomeTeamMoneyLine': 248,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:32:04',
#   'GameEndDateTime': '2019-03-29T21:38:25',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54170,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T19:10:00',
#   'AwayTeam': 'COL',
#   'HomeTeam': 'MIA',
#   'AwayTeamID': 23,
#   'HomeTeamID': 22,
#   'RescheduledGameID': None,
#   'StadiumID': 57,
#   'Channel': 'ATRM,FSFL',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 15,
#   'HomeTeamRuns': 3,
#   'AwayTeamHits': 18,
#   'HomeTeamHits': 5,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10005351,
#   'LosingPitcherID': 10003280,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10005351,
#   'HomeTeamProbablePitcherID': 10008547,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10005351,
#   'HomeTeamStartingPitcherID': 10008547,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': -263,
#   'HomeTeamMoneyLine': 237,
#   'ForecastTempLow': 107,
#   'ForecastTempHigh': 111,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 107,
#   'ForecastWindSpeed': 11,
#   'ForecastWindDirection': 98,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054170,
#   'GlobalAwayTeamID': 10000023,
#   'GlobalHomeTeamID': 10000022,
#   'PointSpreadAwayTeamMoneyLine': 168,
#   'PointSpreadHomeTeamMoneyLine': -202,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:32:06',
#   'GameEndDateTime': '2019-03-29T22:16:37',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54168,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T19:10:00',
#   'AwayTeam': 'HOU',
#   'HomeTeam': 'TB',
#   'AwayTeamID': 30,
#   'HomeTeamID': 11,
#   'RescheduledGameID': None,
#   'StadiumID': 18,
#   'Channel': 'ATSW,SUN',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 5,
#   'HomeTeamRuns': 10,
#   'AwayTeamHits': 15,
#   'HomeTeamHits': 15,
#   'AwayTeamErrors': 5,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000981,
#   'LosingPitcherID': 10000970,
#   'SavingPitcherID': 10007373,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000970,
#   'HomeTeamProbablePitcherID': 10000981,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000970,
#   'HomeTeamStartingPitcherID': 10000981,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': -226,
#   'HomeTeamMoneyLine': 204,
#   'ForecastTempLow': 111,
#   'ForecastTempHigh': 112,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 111,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 98,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054168,
#   'GlobalAwayTeamID': 10000030,
#   'GlobalHomeTeamID': 10000011,
#   'PointSpreadAwayTeamMoneyLine': 188,
#   'PointSpreadHomeTeamMoneyLine': -220,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:32:09',
#   'GameEndDateTime': '2019-03-29T21:49:50',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54171,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T20:10:00',
#   'AwayTeam': 'STL',
#   'HomeTeam': 'MIL',
#   'AwayTeamID': 31,
#   'HomeTeamID': 32,
#   'RescheduledGameID': None,
#   'StadiumID': 19,
#   'Channel': 'FSMW,FSWI',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 14,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 22,
#   'HomeTeamHits': 13,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10005357,
#   'LosingPitcherID': 10002067,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10005822,
#   'HomeTeamProbablePitcherID': 10006935,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10005822,
#   'HomeTeamStartingPitcherID': 10006935,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 13.6,
#   'AwayTeamMoneyLine': -168,
#   'HomeTeamMoneyLine': -168,
#   'ForecastTempLow': 53,
#   'ForecastTempHigh': 66,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 46,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 67,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054171,
#   'GlobalAwayTeamID': 10000031,
#   'GlobalHomeTeamID': 10000032,
#   'PointSpreadAwayTeamMoneyLine': 237,
#   'PointSpreadHomeTeamMoneyLine': -273,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:32:12',
#   'GameEndDateTime': '2019-03-29T23:54:58',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54172,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T22:07:00',
#   'AwayTeam': 'LAA',
#   'HomeTeam': 'OAK',
#   'AwayTeamID': 21,
#   'HomeTeamID': 24,
#   'RescheduledGameID': None,
#   'StadiumID': 23,
#   'Channel': 'CSCA,FSW',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 15,
#   'HomeTeamRuns': 5,
#   'AwayTeamHits': 16,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000804,
#   'LosingPitcherID': 10000429,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000794,
#   'HomeTeamProbablePitcherID': 10001290,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000794,
#   'HomeTeamStartingPitcherID': 10001290,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 13.6,
#   'AwayTeamMoneyLine': -168,
#   'HomeTeamMoneyLine': -168,
#   'ForecastTempLow': 87,
#   'ForecastTempHigh': 87,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 87,
#   'ForecastWindSpeed': 16,
#   'ForecastWindDirection': 489,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054172,
#   'GlobalAwayTeamID': 10000021,
#   'GlobalHomeTeamID': 10000024,
#   'PointSpreadAwayTeamMoneyLine': 242,
#   'PointSpreadHomeTeamMoneyLine': -281,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:32:14',
#   'GameEndDateTime': '2019-03-30T01:02:45',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54167,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T22:10:00',
#   'AwayTeam': 'ARI',
#   'HomeTeam': 'LAD',
#   'AwayTeamID': 14,
#   'HomeTeamID': 1,
#   'RescheduledGameID': None,
#   'StadiumID': 31,
#   'Channel': 'FSAZ,SNLA',
#   'Inning': 13,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 13,
#   'HomeTeamRuns': 10,
#   'AwayTeamHits': 16,
#   'HomeTeamHits': 18,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10001186,
#   'LosingPitcherID': 10000612,
#   'SavingPitcherID': 10000514,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000020,
#   'HomeTeamProbablePitcherID': 10005290,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000020,
#   'HomeTeamStartingPitcherID': 10005290,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': 245,
#   'HomeTeamMoneyLine': -273,
#   'ForecastTempLow': 82,
#   'ForecastTempHigh': 90,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 82,
#   'ForecastWindSpeed': 5,
#   'ForecastWindDirection': 481,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054167,
#   'GlobalAwayTeamID': 10000014,
#   'GlobalHomeTeamID': 10000001,
#   'PointSpreadAwayTeamMoneyLine': -232,
#   'PointSpreadHomeTeamMoneyLine': 200,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T03:32:17',
#   'GameEndDateTime': '2019-03-30T04:20:22',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 54174,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-03-29T00:00:00',
#   'DateTime': '2019-03-29T22:10:00',
#   'AwayTeam': 'SF',
#   'HomeTeam': 'SD',
#   'AwayTeamID': 15,
#   'HomeTeamID': 33,
#   'RescheduledGameID': None,
#   'StadiumID': 1,
#   'Channel': 'FSSD',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 3,
#   'HomeTeamRuns': 10,
#   'AwayTeamHits': 15,
#   'HomeTeamHits': 13,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10007081,
#   'LosingPitcherID': 10001243,
#   'SavingPitcherID': 10001208,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001243,
#   'HomeTeamProbablePitcherID': 10007081,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001243,
#   'HomeTeamStartingPitcherID': 10007081,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': 239,
#   'HomeTeamMoneyLine': -264,
#   'ForecastTempLow': 75,
#   'ForecastTempHigh': 82,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 74,
#   'ForecastWindSpeed': 8,
#   'ForecastWindDirection': 434,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10054174,
#   'GlobalAwayTeamID': 10000015,
#   'GlobalHomeTeamID': 10000033,
#   'PointSpreadAwayTeamMoneyLine': -244,
#   'PointSpreadHomeTeamMoneyLine': 212,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-03-30T01:25:39',
# ...
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T14:10:00',
#   'AwayTeam': 'PIT',
#   'HomeTeam': 'MIL',
#   'AwayTeamID': 4,
#   'HomeTeamID': 32,
#   'RescheduledGameID': None,
#   'StadiumID': 19,
#   'Channel': 'ATPT,FSWI',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 5,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 14,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10000702,
#   'LosingPitcherID': 10000977,
#   'SavingPitcherID': 10006039,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10005587,
#   'HomeTeamProbablePitcherID': 10000001,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10005587,
#   'HomeTeamStartingPitcherID': 10000001,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 15.2,
#   'AwayTeamMoneyLine': 282,
#   'HomeTeamMoneyLine': -314,
#   'ForecastTempLow': 96,
#   'ForecastTempHigh': 98,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 96,
#   'ForecastWindSpeed': 5,
#   'ForecastWindDirection': 495,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055128,
#   'GlobalAwayTeamID': 10000004,
#   'GlobalHomeTeamID': 10000032,
#   'PointSpreadAwayTeamMoneyLine': -191,
#   'PointSpreadHomeTeamMoneyLine': -162,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T05:47:50',
#   'GameEndDateTime': '2019-06-09T17:05:15',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55119,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T14:15:00',
#   'AwayTeam': 'CHW',
#   'HomeTeam': 'KC',
#   'AwayTeamID': 16,
#   'HomeTeamID': 5,
#   'RescheduledGameID': None,
#   'StadiumID': 33,
#   'Channel': 'WGN,FSKC',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 13,
#   'HomeTeamRuns': 5,
#   'AwayTeamHits': 19,
#   'HomeTeamHits': 15,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 5,
#   'WinningPitcherID': 10006183,
#   'LosingPitcherID': 10007389,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10006183,
#   'HomeTeamProbablePitcherID': 10007389,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10006183,
#   'HomeTeamStartingPitcherID': 10007389,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 15.2,
#   'AwayTeamMoneyLine': 197,
#   'HomeTeamMoneyLine': -218,
#   'ForecastTempLow': 101,
#   'ForecastTempHigh': 106,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 101,
#   'ForecastWindSpeed': 22,
#   'ForecastWindDirection': 559,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055119,
#   'GlobalAwayTeamID': 10000016,
#   'GlobalHomeTeamID': 10000005,
#   'PointSpreadAwayTeamMoneyLine': -253,
#   'PointSpreadHomeTeamMoneyLine': 221,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T05:48:03',
#   'GameEndDateTime': '2019-06-09T17:23:07',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55120,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T15:05:00',
#   'AwayTeam': 'OAK',
#   'HomeTeam': 'TEX',
#   'AwayTeamID': 24,
#   'HomeTeamID': 28,
#   'RescheduledGameID': None,
#   'StadiumID': 21,
#   'Channel': 'CSCA,FSSW',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 14,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 18,
#   'HomeTeamHits': 24,
#   'AwayTeamErrors': 5,
#   'HomeTeamErrors': 5,
#   'WinningPitcherID': 10000242,
#   'LosingPitcherID': 10001207,
#   'SavingPitcherID': 10001352,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000242,
#   'HomeTeamProbablePitcherID': 10001207,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000242,
#   'HomeTeamStartingPitcherID': 10001207,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 17.6,
#   'AwayTeamMoneyLine': -329,
#   'HomeTeamMoneyLine': 293,
#   'ForecastTempLow': 114,
#   'ForecastTempHigh': 120,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 114,
#   'ForecastWindSpeed': 34,
#   'ForecastWindDirection': 22,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055120,
#   'GlobalAwayTeamID': 10000024,
#   'GlobalHomeTeamID': 10000028,
#   'PointSpreadAwayTeamMoneyLine': -234,
#   'PointSpreadHomeTeamMoneyLine': 202,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T05:48:17',
#   'GameEndDateTime': '2019-06-09T19:38:45',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55130,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T16:05:00',
#   'AwayTeam': 'LAD',
#   'HomeTeam': 'SF',
#   'AwayTeamID': 1,
#   'HomeTeamID': 15,
#   'RescheduledGameID': None,
#   'StadiumID': 13,
#   'Channel': 'SNLA,CSBA',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 3,
#   'HomeTeamRuns': 0,
#   'AwayTeamHits': 15,
#   'HomeTeamHits': 13,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 0,
#   'WinningPitcherID': 10005607,
#   'LosingPitcherID': 10001105,
#   'SavingPitcherID': 10000617,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10005607,
#   'HomeTeamProbablePitcherID': 10001105,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10005607,
#   'HomeTeamStartingPitcherID': 10001105,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 11.2,
#   'AwayTeamMoneyLine': -256,
#   'HomeTeamMoneyLine': 231,
#   'ForecastTempLow': 115,
#   'ForecastTempHigh': 125,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 125,
#   'ForecastWindSpeed': 15,
#   'ForecastWindDirection': 457,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055130,
#   'GlobalAwayTeamID': 10000001,
#   'GlobalHomeTeamID': 10000015,
#   'PointSpreadAwayTeamMoneyLine': 160,
#   'PointSpreadHomeTeamMoneyLine': -192,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-23T05:56:20',
#   'GameEndDateTime': '2019-06-09T18:39:33',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55131,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T16:07:00',
#   'AwayTeam': 'SEA',
#   'HomeTeam': 'LAA',
#   'AwayTeamID': 13,
#   'HomeTeamID': 21,
#   'RescheduledGameID': None,
#   'StadiumID': 28,
#   'Channel': 'RTNW,FSW',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 14,
#   'HomeTeamRuns': 8,
#   'AwayTeamHits': 21,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 0,
#   'HomeTeamErrors': 3,
#   'WinningPitcherID': 10000556,
#   'LosingPitcherID': 10007341,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000556,
#   'HomeTeamProbablePitcherID': 10007341,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000556,
#   'HomeTeamStartingPitcherID': 10007341,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 16.8,
#   'AwayTeamMoneyLine': 226,
#   'HomeTeamMoneyLine': -250,
#   'ForecastTempLow': 114,
#   'ForecastTempHigh': 128,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 114,
#   'ForecastWindSpeed': 11,
#   'ForecastWindDirection': 338,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055131,
#   'GlobalAwayTeamID': 10000013,
#   'GlobalHomeTeamID': 10000021,
#   'PointSpreadAwayTeamMoneyLine': -224,
#   'PointSpreadHomeTeamMoneyLine': 192,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T05:48:43',
#   'GameEndDateTime': '2019-06-09T19:26:47',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55132,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T16:10:00',
#   'AwayTeam': 'WSH',
#   'HomeTeam': 'SD',
#   'AwayTeamID': 35,
#   'HomeTeamID': 33,
#   'RescheduledGameID': None,
#   'StadiumID': 1,
#   'Channel': 'MASN2,FSSD',
#   'Inning': 9,
#   'InningHalf': 'B',
#   'AwayTeamRuns': 13,
#   'HomeTeamRuns': 5,
#   'AwayTeamHits': 13,
#   'HomeTeamHits': 11,
#   'AwayTeamErrors': 3,
#   'HomeTeamErrors': 3,
#   'WinningPitcherID': 10001350,
#   'LosingPitcherID': 10001348,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001350,
#   'HomeTeamProbablePitcherID': 10003550,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001350,
#   'HomeTeamStartingPitcherID': 10003550,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': 3.9,
#   'OverUnder': 12.8,
#   'AwayTeamMoneyLine': -247,
#   'HomeTeamMoneyLine': 223,
#   'ForecastTempLow': 99,
#   'ForecastTempHigh': 107,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 107,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 402,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055132,
#   'GlobalAwayTeamID': 10000035,
#   'GlobalHomeTeamID': 10000033,
#   'PointSpreadAwayTeamMoneyLine': 167,
#   'PointSpreadHomeTeamMoneyLine': -199,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-12T05:48:57',
#   'GameEndDateTime': '2019-06-09T19:09:43',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55129,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Final',
#   'Day': '2019-06-09T00:00:00',
#   'DateTime': '2019-06-09T19:08:00',
#   'AwayTeam': 'STL',
#   'HomeTeam': 'CHC',
#   'AwayTeamID': 31,
#   'HomeTeamID': 9,
#   'RescheduledGameID': None,
#   'StadiumID': 27,
#   'Channel': 'ESPN',
#   'Inning': 9,
#   'InningHalf': 'T',
#   'AwayTeamRuns': 3,
#   'HomeTeamRuns': 13,
#   'AwayTeamHits': 14,
#   'HomeTeamHits': 14,
#   'AwayTeamErrors': 5,
#   'HomeTeamErrors': 3,
#   'WinningPitcherID': 10003212,
#   'LosingPitcherID': 10001162,
#   'SavingPitcherID': 10000203,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10001162,
#   'HomeTeamProbablePitcherID': 10003212,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10001162,
#   'HomeTeamStartingPitcherID': 10003212,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 12.8,
#   'AwayTeamMoneyLine': 261,
#   'HomeTeamMoneyLine': -290,
#   'ForecastTempLow': 101,
#   'ForecastTempHigh': 111,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 101,
#   'ForecastWindSpeed': 8,
#   'ForecastWindDirection': 67,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055129,
#   'GlobalAwayTeamID': 10000031,
#   'GlobalHomeTeamID': 10000009,
#   'PointSpreadAwayTeamMoneyLine': -210,
#   'PointSpreadHomeTeamMoneyLine': 176,
#   'LastPlay': 'Scrambled',
#   'IsClosed': True,
#   'Updated': '2019-06-09T22:23:52',
#   'GameEndDateTime': '2019-06-09T21:57:56',
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  {'GameID': 55135,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Status': 'Postponed',
#   'Day': '2019-06-10T00:00:00',
#   'DateTime': '2019-06-10T19:05:00',
#   'AwayTeam': 'NYM',
#   'HomeTeam': 'NYY',
#   'AwayTeamID': 18,
#   'HomeTeamID': 29,
#   'RescheduledGameID': 56618,
#   'StadiumID': 35,
#   'Channel': 'SNY,YES',
#   'Inning': None,
#   'InningHalf': None,
#   'AwayTeamRuns': None,
#   'HomeTeamRuns': None,
#   'AwayTeamHits': None,
#   'HomeTeamHits': None,
#   'AwayTeamErrors': None,
#   'HomeTeamErrors': None,
#   'WinningPitcherID': None,
#   'LosingPitcherID': None,
#   'SavingPitcherID': None,
#   'Attendance': None,
#   'AwayTeamProbablePitcherID': 10000520,
#   'HomeTeamProbablePitcherID': 10000850,
#   'Outs': None,
#   'Balls': None,
#   'Strikes': None,
#   'CurrentPitcherID': None,
#   'CurrentHitterID': None,
#   'AwayTeamStartingPitcherID': 10000520,
#   'HomeTeamStartingPitcherID': 10000850,
#   'CurrentPitchingTeamID': None,
#   'CurrentHittingTeamID': None,
#   'PointSpread': -2.4,
#   'OverUnder': 14.4,
#   'AwayTeamMoneyLine': 266,
#   'HomeTeamMoneyLine': -297,
#   'ForecastTempLow': 109,
#   'ForecastTempHigh': 111,
#   'ForecastDescription': 'Scrambled',
#   'ForecastWindChill': 109,
#   'ForecastWindSpeed': 13,
#   'ForecastWindDirection': 229,
#   'RescheduledFromGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'CurrentPitcher': 'Scrambled',
#   'CurrentHitter': 'Scrambled',
#   'WinningPitcher': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'SavingPitcher': 'Scrambled',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'GlobalGameID': 10055135,
#   'GlobalAwayTeamID': 10000018,
#   'GlobalHomeTeamID': 10000029,
#   'PointSpreadAwayTeamMoneyLine': -200,
#   'PointSpreadHomeTeamMoneyLine': 168,
#   'LastPlay': 'Scrambled',
#   'IsClosed': False,
#   'Updated': '2019-06-11T15:51:07',
#   'GameEndDateTime': None,
#   'HomeRotationNumber': None,
#   'AwayRotationNumber': None,
#   'Innings': []},
#  ...]

# %%
parsed_games_mlb = []
for game in mlb_data:
    parsed_game = {}
    parsed_game['game_id'] = game['GameID']
    parsed_game['month'] = game['DateTime'][5:7]
    parsed_game['away_team'] = game['AwayTeam']
    parsed_game['away_team_score'] = game['AwayTeamRuns']
    parsed_game['away_team_moneyline'] = game['PointSpreadAwayTeamMoneyLine']
    parsed_game['home_team'] = game['HomeTeam']
    parsed_game['home_team_score'] = game['HomeTeamRuns']
    parsed_game['home_team_moneyline'] = game['PointSpreadHomeTeamMoneyLine']
    parsed_game['spread'] = game['PointSpread']
    parsed_games_mlb.append(parsed_game)

# %%
parsed_games_mlb
# Out:
# [{'game_id': 54052,
#   'month': '03',
#   'away_team': 'SEA',
#   'away_team_score': 14,
#   'away_team_moneyline': -263,
#   'home_team': 'OAK',
#   'home_team_score': 11,
#   'home_team_moneyline': 237,
#   'spread': -2.4},
#  {'game_id': 54066,
#   'month': '03',
#   'away_team': 'SEA',
#   'away_team_score': 13,
#   'away_team_moneyline': -372,
#   'home_team': 'OAK',
#   'home_team_score': 10,
#   'home_team_moneyline': 332,
#   'spread': -2.4},
#  {'game_id': 54155,
#   'month': '03',
#   'away_team': 'BAL',
#   'away_team_score': 5,
#   'away_team_moneyline': 258,
#   'home_team': 'NYY',
#   'home_team_score': 11,
#   'home_team_moneyline': -301,
#   'spread': -2.4},
#  {'game_id': 54156,
#   'month': '03',
#   'away_team': 'NYM',
#   'away_team_score': 5,
#   'away_team_moneyline': -330,
#   'home_team': 'WSH',
#   'home_team_score': 0,
#   'home_team_moneyline': 295,
#   'spread': -2.4},
#  {'game_id': 54157,
#   'month': '03',
#   'away_team': 'STL',
#   'away_team_score': 10,
#   'away_team_moneyline': -305,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': 274,
#   'spread': -2.4},
#  {'game_id': 54158,
#   'month': '03',
#   'away_team': 'ATL',
#   'away_team_score': 10,
#   'away_team_moneyline': -208,
#   'home_team': 'PHI',
#   'home_team_score': 16,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 54159,
#   'month': '03',
#   'away_team': 'DET',
#   'away_team_score': 5,
#   'away_team_moneyline': -244,
#   'home_team': 'TOR',
#   'home_team_score': 0,
#   'home_team_moneyline': 213,
#   'spread': -2.4},
#  {'game_id': 54154,
#   'month': '03',
#   'away_team': 'HOU',
#   'away_team_score': 13,
#   'away_team_moneyline': 213,
#   'home_team': 'TB',
#   'home_team_score': 3,
#   'home_team_moneyline': -260,
#   'spread': 3.9},
#  {'game_id': 54153,
#   'month': '03',
#   'away_team': 'CHC',
#   'away_team_score': 19,
#   'away_team_moneyline': 205,
#   'home_team': 'TEX',
#   'home_team_score': 10,
#   'home_team_moneyline': -240,
#   'spread': 3.9},
#  {'game_id': 54161,
#   'month': '03',
#   'away_team': 'LAA',
#   'away_team_score': 0,
#   'away_team_moneyline': -353,
#   'home_team': 'OAK',
#   'home_team_score': 10,
#   'home_team_moneyline': 298,
#   'spread': -2.4},
#  {'game_id': 54163,
#   'month': '03',
#   'away_team': 'PIT',
#   'away_team_score': 8,
#   'away_team_moneyline': -329,
#   'home_team': 'CIN',
#   'home_team_score': 13,
#   'home_team_moneyline': 281,
#   'spread': -2.4},
#  {'game_id': 54160,
#   'month': '03',
#   'away_team': 'ARI',
#   'away_team_score': 13,
#   'away_team_moneyline': -252,
#   'home_team': 'LAD',
#   'home_team_score': 19,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54165,
#   'month': '03',
#   'away_team': 'COL',
#   'away_team_score': 15,
#   'away_team_moneyline': 197,
#   'home_team': 'MIA',
#   'home_team_score': 8,
#   'home_team_moneyline': -226,
#   'spread': 3.9},
#  {'game_id': 54162,
#   'month': '03',
#   'away_team': 'CLE',
#   'away_team_score': 0,
#   'away_team_moneyline': 273,
#   'home_team': 'MIN',
#   'home_team_score': 5,
#   'home_team_moneyline': -321,
#   'spread': 3.9},
#  {'game_id': 54164,
#   'month': '03',
#   'away_team': 'SF',
#   'away_team_score': 0,
#   'away_team_moneyline': -298,
#   'home_team': 'SD',
#   'home_team_score': 5,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54152,
#   'month': '03',
#   'away_team': 'CHW',
#   'away_team_score': 8,
#   'away_team_moneyline': -306,
#   'home_team': 'KC',
#   'home_team_score': 13,
#   'home_team_moneyline': 274,
#   'spread': -2.4},
#  {'game_id': 54166,
#   'month': '03',
#   'away_team': 'BOS',
#   'away_team_score': 10,
#   'away_team_moneyline': -188,
#   'home_team': 'SEA',
#   'home_team_score': 19,
#   'home_team_moneyline': 164,
#   'spread': 3.9},
#  {'game_id': 54169,
#   'month': '03',
#   'away_team': 'DET',
#   'away_team_score': 0,
#   'away_team_moneyline': -289,
#   'home_team': 'TOR',
#   'home_team_score': 15,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54170,
#   'month': '03',
#   'away_team': 'COL',
#   'away_team_score': 15,
#   'away_team_moneyline': 168,
#   'home_team': 'MIA',
#   'home_team_score': 3,
#   'home_team_moneyline': -202,
#   'spread': 3.9},
#  {'game_id': 54168,
#   'month': '03',
#   'away_team': 'HOU',
#   'away_team_score': 5,
#   'away_team_moneyline': 188,
#   'home_team': 'TB',
#   'home_team_score': 10,
#   'home_team_moneyline': -220,
#   'spread': 3.9},
#  {'game_id': 54171,
#   'month': '03',
#   'away_team': 'STL',
#   'away_team_score': 14,
#   'away_team_moneyline': 237,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': -273,
#   'spread': 3.9},
#  {'game_id': 54172,
#   'month': '03',
#   'away_team': 'LAA',
#   'away_team_score': 15,
#   'away_team_moneyline': 242,
#   'home_team': 'OAK',
#   'home_team_score': 5,
#   'home_team_moneyline': -281,
#   'spread': 3.9},
#  {'game_id': 54167,
#   'month': '03',
#   'away_team': 'ARI',
#   'away_team_score': 13,
#   'away_team_moneyline': -232,
#   'home_team': 'LAD',
#   'home_team_score': 10,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54174,
#   'month': '03',
#   'away_team': 'SF',
#   'away_team_score': 3,
#   'away_team_moneyline': -244,
#   'home_team': 'SD',
#   'home_team_score': 10,
#   'home_team_moneyline': 212,
#   'spread': -2.4},
#  {'game_id': 54173,
#   'month': '03',
#   'away_team': 'BOS',
#   'away_team_score': 11,
#   'away_team_moneyline': 184,
#   'home_team': 'SEA',
#   'home_team_score': 15,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 54177,
#   'month': '03',
#   'away_team': 'BAL',
#   'away_team_score': 13,
#   'away_team_moneyline': 232,
#   'home_team': 'NYY',
#   'home_team_score': 8,
#   'home_team_moneyline': -268,
#   'spread': -2.4},
#  {'game_id': 54181,
#   'month': '03',
#   'away_team': 'NYM',
#   'away_team_score': 18,
#   'away_team_moneyline': -337,
#   'home_team': 'WSH',
#   'home_team_score': 13,
#   'home_team_moneyline': 289,
#   'spread': -2.4},
#  {'game_id': 54182,
#   'month': '03',
#   'away_team': 'PIT',
#   'away_team_score': None,
#   'away_team_moneyline': -281,
#   'home_team': 'CIN',
#   'home_team_score': None,
#   'home_team_moneyline': 242,
#   'spread': -2.4},
#  {'game_id': 54176,
#   'month': '03',
#   'away_team': 'CLE',
#   'away_team_score': 5,
#   'away_team_moneyline': -393,
#   'home_team': 'MIN',
#   'home_team_score': 3,
#   'home_team_moneyline': 349,
#   'spread': -2.4},
#  {'game_id': 54175,
#   'month': '03',
#   'away_team': 'CHW',
#   'away_team_score': 15,
#   'away_team_moneyline': -279,
#   'home_team': 'KC',
#   'home_team_score': 13,
#   'home_team_moneyline': 252,
#   'spread': -2.4},
#  {'game_id': 54183,
#   'month': '03',
#   'away_team': 'DET',
#   'away_team_score': 0,
#   'away_team_moneyline': -264,
#   'home_team': 'TOR',
#   'home_team_score': 8,
#   'home_team_moneyline': 239,
#   'spread': -2.4},
#  {'game_id': 54184,
#   'month': '03',
#   'away_team': 'ATL',
#   'away_team_score': 15,
#   'away_team_moneyline': -252,
#   'home_team': 'PHI',
#   'home_team_score': 13,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54185,
#   'month': '03',
#   'away_team': 'COL',
#   'away_team_score': 8,
#   'away_team_moneyline': 220,
#   'home_team': 'MIA',
#   'home_team_score': 11,
#   'home_team_moneyline': -242,
#   'spread': 3.9},
#  {'game_id': 54180,
#   'month': '03',
#   'away_team': 'HOU',
#   'away_team_score': 3,
#   'away_team_moneyline': 221,
#   'home_team': 'TB',
#   'home_team_score': 8,
#   'home_team_moneyline': -244,
#   'spread': 3.9},
#  {'game_id': 54186,
#   'month': '03',
#   'away_team': 'STL',
#   'away_team_score': 5,
#   'away_team_moneyline': -261,
#   'home_team': 'MIL',
#   'home_team_score': 10,
#   'home_team_moneyline': 236,
#   'spread': -2.4},
#  {'game_id': 54178,
#   'month': '03',
#   'away_team': 'CHC',
#   'away_team_score': 15,
#   'away_team_moneyline': 162,
#   'home_team': 'TEX',
#   'home_team_score': 13,
#   'home_team_moneyline': -178,
#   'spread': 3.9},
#  {'game_id': 54187,
#   'month': '03',
#   'away_team': 'SF',
#   'away_team_score': 8,
#   'away_team_moneyline': -277,
#   'home_team': 'SD',
#   'home_team_score': 5,
#   'home_team_moneyline': 250,
#   'spread': -2.4},
#  {'game_id': 54188,
#   'month': '03',
#   'away_team': 'LAA',
#   'away_team_score': 5,
#   'away_team_moneyline': -300,
#   'home_team': 'OAK',
#   'home_team_score': 10,
#   'home_team_moneyline': 269,
#   'spread': -2.4},
#  {'game_id': 54179,
#   'month': '03',
#   'away_team': 'ARI',
#   'away_team_score': 13,
#   'away_team_moneyline': -183,
#   'home_team': 'LAD',
#   'home_team_score': 29,
#   'home_team_moneyline': 167,
#   'spread': -2.4},
#  {'game_id': 54189,
#   'month': '03',
#   'away_team': 'BOS',
#   'away_team_score': 13,
#   'away_team_moneyline': -162,
#   'home_team': 'SEA',
#   'home_team_score': 15,
#   'home_team_moneyline': -175,
#   'spread': 3.9},
#  {'game_id': 54191,
#   'month': '03',
#   'away_team': 'BAL',
#   'away_team_score': 11,
#   'away_team_moneyline': 216,
#   'home_team': 'NYY',
#   'home_team_score': 13,
#   'home_team_moneyline': -248,
#   'spread': -2.4},
#  {'game_id': 54194,
#   'month': '03',
#   'away_team': 'DET',
#   'away_team_score': 10,
#   'away_team_moneyline': -240,
#   'home_team': 'TOR',
#   'home_team_score': 8,
#   'home_team_moneyline': 208,
#   'spread': -2.4},
#  {'game_id': 54195,
#   'month': '03',
#   'away_team': 'PIT',
#   'away_team_score': 13,
#   'away_team_moneyline': -289,
#   'home_team': 'CIN',
#   'home_team_score': 0,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54196,
#   'month': '03',
#   'away_team': 'COL',
#   'away_team_score': 0,
#   'away_team_moneyline': 168,
#   'home_team': 'MIA',
#   'home_team_score': 8,
#   'home_team_moneyline': -200,
#   'spread': 3.9},
#  {'game_id': 54193,
#   'month': '03',
#   'away_team': 'HOU',
#   'away_team_score': 3,
#   'away_team_moneyline': 212,
#   'home_team': 'TB',
#   'home_team_score': 8,
#   'home_team_moneyline': -248,
#   'spread': 3.9},
#  {'game_id': 54197,
#   'month': '03',
#   'away_team': 'NYM',
#   'away_team_score': 13,
#   'away_team_moneyline': -232,
#   'home_team': 'WSH',
#   'home_team_score': 15,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54198,
#   'month': '03',
#   'away_team': 'STL',
#   'away_team_score': 10,
#   'away_team_moneyline': -345,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': 289,
#   'spread': -2.4},
#  {'game_id': 54199,
#   'month': '03',
#   'away_team': 'CLE',
#   'away_team_score': 8,
#   'away_team_moneyline': 237,
#   'home_team': 'MIN',
#   'home_team_score': 14,
#   'home_team_moneyline': -273,
#   'spread': 3.9},
#  {'game_id': 54190,
#   'month': '03',
#   'away_team': 'CHW',
#   'away_team_score': 15,
#   'away_team_moneyline': -289,
#   'home_team': 'KC',
#   'home_team_score': 8,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54200,
#   'month': '03',
#   'away_team': 'CHC',
#   'away_team_score': 16,
#   'away_team_moneyline': 192,
#   'home_team': 'TEX',
#   'home_team_score': 18,
#   'home_team_moneyline': -224,
#   'spread': 3.9},
#  {'game_id': 54201,
#   'month': '03',
#   'away_team': 'LAA',
#   'away_team_score': 3,
#   'away_team_moneyline': -289,
#   'home_team': 'OAK',
#   'home_team_score': 5,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54192,
#   'month': '03',
#   'away_team': 'ARI',
#   'away_team_score': 11,
#   'away_team_moneyline': -200,
#   'home_team': 'LAD',
#   'home_team_score': 13,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  {'game_id': 54203,
#   'month': '03',
#   'away_team': 'SF',
#   'away_team_score': 3,
#   'away_team_moneyline': -210,
#   'home_team': 'SD',
#   'home_team_score': 8,
#   'home_team_moneyline': 178,
#   'spread': -2.4},
#  {'game_id': 54202,
#   'month': '03',
#   'away_team': 'BOS',
#   'away_team_score': 13,
#   'away_team_moneyline': 176,
#   'home_team': 'SEA',
#   'home_team_score': 16,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54204,
#   'month': '03',
#   'away_team': 'ATL',
#   'away_team_score': 3,
#   'away_team_moneyline': -255,
#   'home_team': 'PHI',
#   'home_team_score': 13,
#   'home_team_moneyline': 223,
#   'spread': -2.4},
#  {'game_id': 54207,
#   'month': '04',
#   'away_team': 'STL',
#   'away_team_score': 15,
#   'away_team_moneyline': -321,
#   'home_team': 'PIT',
#   'home_team_score': 13,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 54208,
#   'month': '04',
#   'away_team': 'CHW',
#   'away_team_score': 8,
#   'away_team_moneyline': -240,
#   'home_team': 'CLE',
#   'home_team_score': 13,
#   'home_team_moneyline': 208,
#   'spread': -2.4},
#  {'game_id': 54209,
#   'month': '04',
#   'away_team': 'DET',
#   'away_team_score': 3,
#   'away_team_moneyline': -175,
#   'home_team': 'NYY',
#   'home_team_score': 8,
#   'home_team_moneyline': -178,
#   'spread': -2.4},
#  {'game_id': 54210,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 10,
#   'away_team_moneyline': 237,
#   'home_team': 'CIN',
#   'home_team_score': 8,
#   'home_team_moneyline': -273,
#   'spread': 3.9},
#  {'game_id': 54212,
#   'month': '04',
#   'away_team': 'BAL',
#   'away_team_score': 15,
#   'away_team_moneyline': -216,
#   'home_team': 'TOR',
#   'home_team_score': 13,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54211,
#   'month': '04',
#   'away_team': 'CHC',
#   'away_team_score': 0,
#   'away_team_moneyline': -337,
#   'home_team': 'ATL',
#   'home_team_score': 13,
#   'home_team_moneyline': 282,
#   'spread': -2.4},
#  {'game_id': 54213,
#   'month': '04',
#   'away_team': 'NYM',
#   'away_team_score': 11,
#   'away_team_moneyline': 199,
#   'home_team': 'MIA',
#   'home_team_score': 8,
#   'home_team_moneyline': -231,
#   'spread': 3.9},
#  {'game_id': 54206,
#   'month': '04',
#   'away_team': 'COL',
#   'away_team_score': 3,
#   'away_team_moneyline': -248,
#   'home_team': 'TB',
#   'home_team_score': 11,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54205,
#   'month': '04',
#   'away_team': 'HOU',
#   'away_team_score': 5,
#   'away_team_moneyline': -197,
#   'home_team': 'TEX',
#   'home_team_score': 3,
#   'home_team_moneyline': 165,
#   'spread': 3.9},
#  {'game_id': 54215,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 0,
#   'away_team_moneyline': 176,
#   'home_team': 'OAK',
#   'home_team_score': 11,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54214,
#   'month': '04',
#   'away_team': 'SF',
#   'away_team_score': 10,
#   'away_team_moneyline': -188,
#   'home_team': 'LAD',
#   'home_team_score': 5,
#   'home_team_moneyline': -165,
#   'spread': -2.4},
#  {'game_id': 54217,
#   'month': '04',
#   'away_team': 'ARI',
#   'away_team_score': 16,
#   'away_team_moneyline': -232,
#   'home_team': 'SD',
#   'home_team_score': 8,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54216,
#   'month': '04',
#   'away_team': 'LAA',
#   'away_team_score': 8,
#   'away_team_moneyline': -337,
#   'home_team': 'SEA',
#   'home_team_score': 15,
#   'home_team_moneyline': 282,
#   'spread': -2.4},
#  {'game_id': 54222,
#   'month': '04',
#   'away_team': 'DET',
#   'away_team_score': 8,
#   'away_team_moneyline': -176,
#   'home_team': 'NYY',
#   'home_team_score': 3,
#   'home_team_moneyline': -176,
#   'spread': -2.4},
#  {'game_id': 54223,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 10,
#   'away_team_moneyline': 231,
#   'home_team': 'CIN',
#   'home_team_score': 8,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 54224,
#   'month': '04',
#   'away_team': 'PHI',
#   'away_team_score': 13,
#   'away_team_moneyline': -220,
#   'home_team': 'WSH',
#   'home_team_score': 5,
#   'home_team_moneyline': 188,
#   'spread': -2.4},
#  {'game_id': 54225,
#   'month': '04',
#   'away_team': 'BAL',
#   'away_team_score': 5,
#   'away_team_moneyline': -191,
#   'home_team': 'TOR',
#   'home_team_score': 3,
#   'home_team_moneyline': -162,
#   'spread': -2.4},
#  {'game_id': 54226,
#   'month': '04',
#   'away_team': 'NYM',
#   'away_team_score': 15,
#   'away_team_moneyline': 184,
#   'home_team': 'MIA',
#   'home_team_score': 13,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 54221,
#   'month': '04',
#   'away_team': 'COL',
#   'away_team_score': 0,
#   'away_team_moneyline': -229,
#   'home_team': 'TB',
#   'home_team_score': 10,
#   'home_team_moneyline': 197,
#   'spread': -2.4},
#  {'game_id': 54219,
#   'month': '04',
#   'away_team': 'HOU',
#   'away_team_score': 10,
#   'away_team_moneyline': -248,
#   'home_team': 'TEX',
#   'home_team_score': 15,
#   'home_team_moneyline': 216,
#   'spread': 3.9},
#  {'game_id': 54218,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 13,
#   'away_team_moneyline': 176,
#   'home_team': 'KC',
#   'home_team_score': 10,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54227,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 0,
#   'away_team_moneyline': -176,
#   'home_team': 'OAK',
#   'home_team_score': 3,
#   'home_team_moneyline': -176,
#   'spread': 3.9},
#  {'game_id': 54220,
#   'month': '04',
#   'away_team': 'SF',
#   'away_team_score': 13,
#   'away_team_moneyline': -248,
#   'home_team': 'LAD',
#   'home_team_score': 15,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54229,
#   'month': '04',
#   'away_team': 'ARI',
#   'away_team_score': 13,
#   'away_team_moneyline': -353,
#   'home_team': 'SD',
#   'home_team_score': 13,
#   'home_team_moneyline': 295,
#   'spread': -2.4},
#  {'game_id': 54228,
#   'month': '04',
#   'away_team': 'LAA',
#   'away_team_score': 3,
#   'away_team_moneyline': -309,
#   'home_team': 'SEA',
#   'home_team_score': 5,
#   'home_team_moneyline': 264,
#   'spread': -2.4},
#  {'game_id': 54235,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 3,
#   'away_team_moneyline': -321,
#   'home_team': 'CIN',
#   'home_team_score': 0,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 54236,
#   'month': '04',
#   'away_team': 'PHI',
#   'away_team_score': 13,
#   'away_team_moneyline': 184,
#   'home_team': 'WSH',
#   'home_team_score': 14,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 54230,
#   'month': '04',
#   'away_team': 'CHW',
#   'away_team_score': 13,
#   'away_team_moneyline': -208,
#   'home_team': 'CLE',
#   'home_team_score': 8,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 54234,
#   'month': '04',
#   'away_team': 'COL',
#   'away_team_score': 3,
#   'away_team_moneyline': -321,
#   'home_team': 'TB',
#   'home_team_score': 0,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 54231,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 11,
#   'away_team_moneyline': 176,
#   'home_team': 'KC',
#   'home_team_score': 15,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54237,
#   'month': '04',
#   'away_team': 'ARI',
#   'away_team_score': 3,
#   'away_team_moneyline': -289,
#   'home_team': 'SD',
#   'home_team_score': 10,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54238,
#   'month': '04',
#   'away_team': 'DET',
#   'away_team_score': 5,
#   'away_team_moneyline': -200,
#   'home_team': 'NYY',
#   'home_team_score': 3,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  {'game_id': 54239,
#   'month': '04',
#   'away_team': 'BAL',
#   'away_team_score': 8,
#   'away_team_moneyline': -248,
#   'home_team': 'TOR',
#   'home_team_score': 13,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54240,
#   'month': '04',
#   'away_team': 'NYM',
#   'away_team_score': 15,
#   'away_team_moneyline': -194,
#   'home_team': 'MIA',
#   'home_team_score': 10,
#   'home_team_moneyline': 162,
#   'spread': 3.9},
#  {'game_id': 54242,
#   'month': '04',
#   'away_team': 'STL',
#   'away_team_score': 13,
#   'away_team_moneyline': -385,
#   'home_team': 'PIT',
#   'home_team_score': 10,
#   'home_team_moneyline': 319,
#   'spread': -2.4},
#  {'game_id': 54241,
#   'month': '04',
#   'away_team': 'CHC',
#   'away_team_score': 10,
#   'away_team_moneyline': -281,
#   'home_team': 'ATL',
#   'home_team_score': 15,
#   'home_team_moneyline': 242,
#   'spread': -2.4},
#  {'game_id': 54232,
#   'month': '04',
#   'away_team': 'HOU',
#   'away_team_score': 0,
#   'away_team_moneyline': -224,
#   'home_team': 'TEX',
#   'home_team_score': 10,
#   'home_team_moneyline': 192,
#   'spread': 3.9},
#  {'game_id': 54243,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 15,
#   'away_team_moneyline': 183,
#   'home_team': 'OAK',
#   'home_team_score': 8,
#   'home_team_moneyline': -215,
#   'spread': 3.9},
#  {'game_id': 54233,
#   'month': '04',
#   'away_team': 'SF',
#   'away_team_score': 8,
#   'away_team_moneyline': -200,
#   'home_team': 'LAD',
#   'home_team_score': 13,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  {'game_id': 54246,
#   'month': '04',
#   'away_team': 'KC',
#   'away_team_score': 10,
#   'away_team_moneyline': 228,
#   'home_team': 'DET',
#   'home_team_score': 13,
#   'home_team_moneyline': -261,
#   'spread': 3.9},
#  {'game_id': 54247,
#   'month': '04',
#   'away_team': 'WSH',
#   'away_team_score': 10,
#   'away_team_moneyline': -353,
#   'home_team': 'NYM',
#   'home_team_score': 0,
#   'home_team_moneyline': 295,
#   'spread': -2.4},
#  {'game_id': 54244,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': None,
#   'away_team_moneyline': None,
#   'home_team': 'CHW',
#   'home_team_score': None,
#   'home_team_moneyline': None,
#   'spread': None},
#  {'game_id': 54248,
#   'month': '04',
#   'away_team': 'NYY',
#   'away_team_score': 13,
#   'away_team_moneyline': -221,
#   'home_team': 'BAL',
#   'home_team_score': 10,
#   'home_team_moneyline': 189,
#   'spread': 3.9},
#  {'game_id': 54249,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 8,
#   'away_team_moneyline': 231,
#   'home_team': 'OAK',
#   'home_team_score': 11,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 54250,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': None,
#   'away_team_moneyline': None,
#   'home_team': 'STL',
#   'home_team_score': None,
#   'home_team_moneyline': None,
#   'spread': None},
#  {'game_id': 54245,
#   'month': '04',
#   'away_team': 'TOR',
#   'away_team_score': 3,
#   'away_team_moneyline': -216,
#   'home_team': 'CLE',
#   'home_team_score': 10,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54251,
#   'month': '04',
#   'away_team': 'CIN',
#   'away_team_score': 0,
#   'away_team_moneyline': 242,
#   'home_team': 'PIT',
#   'home_team_score': 5,
#   'home_team_moneyline': -281,
#   'spread': 3.9},
#  {'game_id': 54252,
#   'month': '04',
#   'away_team': 'CHC',
#   'away_team_score': 10,
#   'away_team_moneyline': -305,
#   'home_team': 'ATL',
#   'home_team_score': 14,
#   'home_team_moneyline': 261,
#   'spread': -2.4},
#  {'game_id': 54253,
#   'month': '04',
#   'away_team': 'TEX',
#   'away_team_score': 18,
#   'away_team_moneyline': -216,
#   'home_team': 'LAA',
#   'home_team_score': 10,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 56594,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 13,
#   'away_team_moneyline': 200,
#   'home_team': 'CHW',
#   'home_team_score': 16,
#   'home_team_moneyline': -232,
#   'spread': 3.9},
#  {'game_id': 54256,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 16,
#   'away_team_moneyline': 184,
#   'home_team': 'COL',
#   'home_team_score': 15,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 56595,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 13,
#   'away_team_moneyline': -208,
#   'home_team': 'STL',
#   'home_team_score': 8,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 54257,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 13,
#   'away_team_moneyline': 224,
#   'home_team': 'SF',
#   'home_team_score': 5,
#   'home_team_moneyline': -256,
#   'spread': 3.9},
#  {'game_id': 54258,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 10,
#   'away_team_moneyline': -226,
#   'home_team': 'PHI',
#   'home_team_score': 16,
#   'home_team_moneyline': 192,
#   'spread': -2.4},
#  {'game_id': 54259,
#   'month': '04',
#   'away_team': 'CIN',
#   'away_team_score': 0,
#   'away_team_moneyline': -273,
#   'home_team': 'PIT',
#   'home_team_score': 5,
#   'home_team_moneyline': 237,
#   'spread': -2.4},
#  {'game_id': 54260,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 13,
#   'away_team_moneyline': 191,
#   'home_team': 'ARI',
#   'home_team_score': 24,
#   'home_team_moneyline': -223,
#   'spread': 3.9},
#  {'game_id': 54254,
#   'month': '04',
#   'away_team': 'TOR',
#   'away_team_score': 5,
#   'away_team_moneyline': -269,
#   'home_team': 'CLE',
#   'home_team_score': 8,
#   'home_team_moneyline': 234,
#   'spread': -2.4},
#  {'game_id': 54261,
#   'month': '04',
#   'away_team': 'MIA',
#   'away_team_score': 0,
#   'away_team_moneyline': -216,
#   'home_team': 'ATL',
#   'home_team_score': 10,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54255,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 5,
#   'away_team_moneyline': -224,
#   'home_team': 'HOU',
#   'home_team_score': 8,
#   'home_team_moneyline': 192,
#   'spread': -2.4},
#  {'game_id': 54262,
#   'month': '04',
#   'away_team': 'CHC',
#   'away_team_score': 16,
#   'away_team_moneyline': -297,
#   'home_team': 'MIL',
#   'home_team_score': 21,
#   'home_team_moneyline': 256,
#   'spread': -2.4},
#  {'game_id': 54263,
#   'month': '04',
#   'away_team': 'TEX',
#   'away_team_score': 3,
#   'away_team_moneyline': -321,
#   'home_team': 'LAA',
#   'home_team_score': 8,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 54268,
#   'month': '04',
#   'away_team': 'KC',
#   'away_team_score': 10,
#   'away_team_moneyline': -297,
#   'home_team': 'DET',
#   'home_team_score': 11,
#   'home_team_moneyline': 256,
#   'spread': -2.4},
#  {'game_id': 54269,
#   'month': '04',
#   'away_team': 'WSH',
#   'away_team_score': 13,
#   'away_team_moneyline': 213,
#   'home_team': 'NYM',
#   'home_team_score': 15,
#   'home_team_moneyline': -248,
#   'spread': 3.9},
#  {'game_id': 54270,
#   'month': '04',
#   'away_team': 'CIN',
#   'away_team_score': 13,
#   'away_team_moneyline': -329,
#   'home_team': 'PIT',
#   'home_team_score': 15,
#   'home_team_moneyline': 276,
#   'spread': -2.4},
#  {'game_id': 54271,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 15,
#   'away_team_moneyline': -232,
#   'home_team': 'PHI',
#   'home_team_score': 5,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54264,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 14,
#   'away_team_moneyline': 231,
#   'home_team': 'CHW',
#   'home_team_score': 5,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 54272,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 15,
#   'away_team_moneyline': -329,
#   'home_team': 'STL',
#   'home_team_score': 10,
#   'home_team_moneyline': 276,
#   'spread': -2.4},
#  {'game_id': 54278,
#   'month': '04',
#   'away_team': 'TEX',
#   'away_team_score': 3,
#   'away_team_moneyline': -232,
#   'home_team': 'LAA',
#   'home_team_score': 13,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54267,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 10,
#   'away_team_moneyline': 215,
#   'home_team': 'SF',
#   'home_team_score': 15,
#   'home_team_moneyline': -247,
#   'spread': 3.9},
#  {'game_id': 54265,
#   'month': '04',
#   'away_team': 'TOR',
#   'away_team_score': 5,
#   'away_team_moneyline': -192,
#   'home_team': 'CLE',
#   'home_team_score': 11,
#   'home_team_moneyline': 160,
#   'spread': -2.4},
#  {'game_id': 54273,
#   'month': '04',
#   'away_team': 'NYY',
#   'away_team_score': 15,
#   'away_team_moneyline': -181,
#   'home_team': 'BAL',
#   'home_team_score': 10,
#   'home_team_moneyline': -167,
#   'spread': 3.9},
#  {'game_id': 54266,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 0,
#   'away_team_moneyline': -250,
#   'home_team': 'HOU',
#   'home_team_score': 15,
#   'home_team_moneyline': 220,
#   'spread': -2.4},
#  {'game_id': 54274,
#   'month': '04',
#   'away_team': 'CHC',
#   'away_team_score': 22,
#   'away_team_moneyline': -297,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': 256,
#   'spread': -2.4},
#  {'game_id': 54275,
#   'month': '04',
#   'away_team': 'MIA',
#   'away_team_score': 10,
#   'away_team_moneyline': -208,
#   'home_team': 'ATL',
#   'home_team_score': 5,
#   'home_team_moneyline': 178,
#   'spread': -2.4},
#  {'game_id': 54277,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 10,
#   'away_team_moneyline': 191,
#   'home_team': 'ARI',
#   'home_team_score': 13,
#   'home_team_moneyline': -223,
#   'spread': 3.9},
#  {'game_id': 54276,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 11,
#   'away_team_moneyline': 205,
#   'home_team': 'COL',
#   'home_team_score': 5,
#   'home_team_moneyline': -237,
#   'spread': 3.9},
#  {'game_id': 54282,
#   'month': '04',
#   'away_team': 'NYY',
#   'away_team_score': 24,
#   'away_team_moneyline': -191,
#   'home_team': 'BAL',
#   'home_team_score': 8,
#   'home_team_moneyline': -162,
#   'spread': 3.9},
#  {'game_id': 54283,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 3,
#   'away_team_moneyline': -289,
#   'home_team': 'PHI',
#   'home_team_score': 5,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54280,
#   'month': '04',
#   'away_team': 'TOR',
#   'away_team_score': 3,
#   'away_team_moneyline': -236,
#   'home_team': 'CLE',
#   'home_team_score': 8,
#   'home_team_moneyline': 205,
#   'spread': -2.4},
#  {'game_id': 54284,
#   'month': '04',
#   'away_team': 'KC',
#   'away_team_score': 3,
#   'away_team_moneyline': 226,
#   'home_team': 'DET',
#   'home_team_score': 8,
#   'home_team_moneyline': -258,
#   'spread': 3.9},
#  {'game_id': 54285,
#   'month': '04',
#   'away_team': 'WSH',
#   'away_team_score': 19,
#   'away_team_moneyline': 200,
#   'home_team': 'NYM',
#   'home_team_score': 14,
#   'home_team_moneyline': -232,
#   'spread': 3.9},
#  {'game_id': 54286,
#   'month': '04',
#   'away_team': 'MIA',
#   'away_team_score': 8,
#   'away_team_moneyline': -216,
#   'home_team': 'ATL',
#   'home_team_score': 10,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54287,
#   'month': '04',
#   'away_team': 'CIN',
#   'away_team_score': 13,
#   'away_team_moneyline': -248,
#   'home_team': 'PIT',
#   'home_team_score': 11,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54279,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 19,
#   'away_team_moneyline': -281,
#   'home_team': 'CHW',
#   'home_team_score': 13,
#   'home_team_moneyline': 242,
#   'spread': -2.4},
#  {'game_id': 54281,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 13,
#   'away_team_moneyline': -200,
#   'home_team': 'HOU',
#   'home_team_score': 14,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  {'game_id': 54288,
#   'month': '04',
#   'away_team': 'CHC',
#   'away_team_score': 5,
#   'away_team_moneyline': -337,
#   'home_team': 'MIL',
#   'home_team_score': 10,
#   'home_team_moneyline': 282,
#   'spread': -2.4},
#  {'game_id': 54289,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 3,
#   'away_team_moneyline': -321,
#   'home_team': 'STL',
#   'home_team_score': 10,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 54290,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 8,
#   'away_team_moneyline': 232,
#   'home_team': 'SF',
#   'home_team_score': 0,
#   'home_team_moneyline': -281,
#   'spread': 3.9},
#  {'game_id': 54291,
#   'month': '04',
#   'away_team': 'TEX',
#   'away_team_score': 5,
#   'away_team_moneyline': -289,
#   'home_team': 'LAA',
#   'home_team_score': 11,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54292,
#   'month': '04',
#   'away_team': 'BOS',
#   'away_team_score': 3,
#   'away_team_moneyline': 224,
#   'home_team': 'ARI',
#   'home_team_score': 0,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 54293,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 19,
#   'away_team_moneyline': -196,
#   'home_team': 'COL',
#   'home_team_score': 15,
#   'home_team_moneyline': 164,
#   'spread': 3.9},
#  {'game_id': 54294,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 13,
#   'away_team_moneyline': -176,
#   'home_team': 'CHW',
#   'home_team_score': 3,
#   'home_team_moneyline': -176,
#   'spread': 3.9},
#  {'game_id': 54296,
#   'month': '04',
#   'away_team': 'PIT',
#   'away_team_score': 0,
#   'away_team_moneyline': -281,
#   'home_team': 'CHC',
#   'home_team_score': 16,
#   'home_team_moneyline': 242,
#   'spread': -2.4},
#  {'game_id': 54298,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 10,
#   'away_team_moneyline': -184,
#   'home_team': 'BAL',
#   'home_team_score': 19,
#   'home_team_moneyline': -168,
#   'spread': 3.9},
#  {'game_id': 54299,
#   'month': '04',
#   'away_team': 'WSH',
#   'away_team_score': 8,
#   'away_team_moneyline': -248,
#   'home_team': 'PHI',
#   'home_team_score': 10,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54297,
#   'month': '04',
#   'away_team': 'NYY',
#   'away_team_score': 8,
#   'away_team_moneyline': -256,
#   'home_team': 'HOU',
#   'home_team_score': 10,
#   'home_team_moneyline': 224,
#   'spread': -2.4},
#  {'game_id': 54300,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 8,
#   'away_team_moneyline': -345,
#   'home_team': 'STL',
#   'home_team_score': 10,
#   'home_team_moneyline': 289,
#   'spread': -2.4},
#  {'game_id': 54295,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 21,
#   'away_team_moneyline': 226,
#   'home_team': 'KC',
#   'home_team_score': 13,
#   'home_team_moneyline': -258,
#   'spread': 3.9},
#  {'game_id': 54301,
#   'month': '04',
#   'away_team': 'ATL',
#   'away_team_score': 13,
#   'away_team_moneyline': -305,
#   'home_team': 'COL',
#   'home_team_score': 15,
#   'home_team_moneyline': 261,
#   'spread': -2.4},
#  {'game_id': 54302,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 15,
#   'away_team_moneyline': -305,
#   'home_team': 'SF',
#   'home_team_score': 13,
#   'home_team_moneyline': 261,
#   'spread': -2.4},
#  {'game_id': 54303,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 5,
#   'away_team_moneyline': 228,
#   'home_team': 'LAA',
#   'home_team_score': 13,
#   'home_team_moneyline': -260,
#   'spread': 3.9},
#  {'game_id': 54306,
#   'month': '04',
#   'away_team': 'CLE',
#   'away_team_score': 13,
#   'away_team_moneyline': 184,
#   'home_team': 'DET',
#   'home_team_score': 5,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 54307,
#   'month': '04',
#   'away_team': 'TOR',
#   'away_team_score': 11,
#   'away_team_moneyline': 186,
#   'home_team': 'BOS',
#   'home_team_score': 13,
#   'home_team_moneyline': -218,
#   'spread': -2.4},
#  {'game_id': 54304,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 16,
#   'away_team_moneyline': -168,
#   'home_team': 'CHW',
#   'home_team_score': 13,
#   'home_team_moneyline': -184,
#   'spread': 3.9},
#  {'game_id': 54308,
#   'month': '04',
#   'away_team': 'MIA',
#   'away_team_score': 0,
#   'away_team_moneyline': -200,
#   'home_team': 'CIN',
#   'home_team_score': 22,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  {'game_id': 54309,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 21,
#   'away_team_moneyline': -184,
#   'home_team': 'BAL',
#   'home_team_score': 5,
#   'home_team_moneyline': -168,
#   'spread': 3.9},
#  {'game_id': 54310,
#   'month': '04',
#   'away_team': 'WSH',
#   'away_team_score': 16,
#   'away_team_moneyline': -269,
#   'home_team': 'PHI',
#   'home_team_score': 15,
#   'home_team_moneyline': 234,
#   'spread': -2.4},
#  {'game_id': 54311,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 22,
#   'away_team_moneyline': -188,
#   'home_team': 'NYM',
#   'home_team_score': 13,
#   'home_team_moneyline': 164,
#   'spread': -2.4},
#  {'game_id': 54312,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 0,
#   'away_team_moneyline': 213,
#   'home_team': 'STL',
#   'home_team_score': 10,
#   'home_team_moneyline': -245,
#   'spread': 3.9},
#  {'game_id': 54313,
#   'month': '04',
#   'away_team': 'NYY',
#   'away_team_score': 8,
#   'away_team_moneyline': -188,
#   'home_team': 'HOU',
#   'home_team_score': 15,
#   'home_team_moneyline': -165,
#   'spread': -2.4},
#  {'game_id': 54305,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 15,
#   'away_team_moneyline': -313,
#   'home_team': 'KC',
#   'home_team_score': 8,
#   'home_team_moneyline': 266,
#   'spread': -2.4},
#  {'game_id': 54314,
#   'month': '04',
#   'away_team': 'ATL',
#   'away_team_score': 11,
#   'away_team_moneyline': -313,
#   'home_team': 'COL',
#   'home_team_score': 3,
#   'home_team_moneyline': 266,
#   'spread': -2.4},
#  {'game_id': 54315,
#   'month': '04',
#   'away_team': 'TEX',
#   'away_team_score': 10,
#   'away_team_moneyline': -248,
#   'home_team': 'ARI',
#   'home_team_score': 13,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54316,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 5,
#   'away_team_moneyline': 192,
#   'home_team': 'SF',
#   'home_team_score': 11,
#   'home_team_moneyline': -224,
#   'spread': 3.9},
#  {'game_id': 54317,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 13,
#   'away_team_moneyline': 176,
#   'home_team': 'LAA',
#   'home_team_score': 18,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54321,
#   'month': '04',
#   'away_team': 'CLE',
#   'away_team_score': 3,
#   'away_team_moneyline': 168,
#   'home_team': 'DET',
#   'home_team_score': 10,
#   'home_team_moneyline': -200,
#   'spread': 3.9},
#  {'game_id': 54318,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 14,
#   'away_team_moneyline': -191,
#   'home_team': 'CHW',
#   'home_team_score': 3,
#   'home_team_moneyline': -162,
#   'spread': 3.9},
#  {'game_id': 54322,
#   'month': '04',
#   'away_team': 'ATL',
#   'away_team_score': None,
#   'away_team_moneyline': 200,
#   'home_team': 'COL',
#   'home_team_score': None,
#   'home_team_moneyline': -232,
#   'spread': 3.9},
#  {'game_id': 54323,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 8,
#   'away_team_moneyline': 242,
#   'home_team': 'SF',
#   'home_team_score': 3,
#   'home_team_moneyline': -281,
#   'spread': 3.9},
#  {'game_id': 54324,
#   'month': '04',
#   'away_team': 'MIA',
#   'away_team_score': 3,
#   'away_team_moneyline': -232,
#   'home_team': 'CIN',
#   'home_team_score': 5,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54325,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 16,
#   'away_team_moneyline': -208,
#   'home_team': 'BAL',
#   'home_team_score': 8,
#   'home_team_moneyline': 176,
#   'spread': 3.9},
#  {'game_id': 54326,
#   'month': '04',
#   'away_team': 'WSH',
#   'away_team_score': 24,
#   'away_team_moneyline': -232,
#   'home_team': 'PHI',
#   'home_team_score': 3,
#   'home_team_moneyline': 200,
#   'spread': -2.4},
#  {'game_id': 54327,
#   'month': '04',
#   'away_team': 'MIN',
#   'away_team_score': 15,
#   'away_team_moneyline': -208,
#   'home_team': 'NYM',
#   'home_team_score': 14,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 54320,
#   'month': '04',
#   'away_team': 'NYY',
#   'away_team_score': 15,
#   'away_team_moneyline': -305,
#   'home_team': 'HOU',
#   'home_team_score': 13,
#   'home_team_moneyline': 261,
#   'spread': -2.4},
#  {'game_id': 54328,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 5,
#   'away_team_moneyline': 237,
#   'home_team': 'STL',
#   'home_team_score': 11,
#   'home_team_moneyline': -273,
#   'spread': 3.9},
#  {'game_id': 54329,
#   'month': '04',
#   'away_team': 'PIT',
#   'away_team_score': 13,
#   'away_team_moneyline': -224,
#   'home_team': 'CHC',
#   'home_team_score': 5,
#   'home_team_moneyline': 192,
#   'spread': -2.4},
#  {'game_id': 54319,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 15,
#   'away_team_moneyline': -165,
#   'home_team': 'KC',
#   'home_team_score': 13,
#   'home_team_moneyline': -173,
#   'spread': 3.9},
#  {'game_id': 54330,
#   'month': '04',
#   'away_team': 'TEX',
#   'away_team_score': 13,
#   'away_team_moneyline': -289,
#   'home_team': 'ARI',
#   'home_team_score': 5,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54331,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 5,
#   'away_team_moneyline': -192,
#   'home_team': 'LAA',
#   'home_team_score': 10,
#   'home_team_moneyline': 160,
#   'spread': 3.9},
#  {'game_id': 54333,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 13,
#   'away_team_moneyline': -168,
#   'home_team': 'BAL',
#   'home_team_score': 13,
#   'home_team_moneyline': -184,
#   'spread': 3.9},
#  {'game_id': 54334,
#   'month': '04',
#   'away_team': 'MIA',
#   'away_team_score': 0,
#   'away_team_moneyline': -216,
#   'home_team': 'CIN',
#   'home_team_score': 13,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54335,
#   'month': '04',
#   'away_team': 'CLE',
#   'away_team_score': 10,
#   'away_team_moneyline': 200,
#   'home_team': 'DET',
#   'home_team_score': 0,
#   'home_team_moneyline': -232,
#   'spread': 3.9},
#  {'game_id': 54332,
#   'month': '04',
#   'away_team': 'SEA',
#   'away_team_score': 11,
#   'away_team_moneyline': 176,
#   'home_team': 'KC',
#   'home_team_score': 15,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54336,
#   'month': '04',
#   'away_team': 'LAD',
#   'away_team_score': 11,
#   'away_team_moneyline': 200,
#   'home_team': 'STL',
#   'home_team_score': 18,
#   'home_team_moneyline': -232,
#   'spread': 3.9},
#  {'game_id': 54337,
#   'month': '04',
#   'away_team': 'TOR',
#   'away_team_score': 15,
#   'away_team_moneyline': -200,
#   'home_team': 'BOS',
#   'home_team_score': 11,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  {'game_id': 54338,
#   'month': '04',
#   'away_team': 'NYM',
#   'away_team_score': 15,
#   'away_team_moneyline': -289,
#   'home_team': 'ATL',
#   'home_team_score': 8,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54339,
#   'month': '04',
#   'away_team': 'PIT',
#   'away_team_score': 0,
#   'away_team_moneyline': -289,
#   'home_team': 'CHC',
#   'home_team_score': 5,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 54340,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 11,
#   'away_team_moneyline': -297,
#   'home_team': 'ARI',
#   'home_team_score': 15,
#   'home_team_moneyline': 256,
#   'spread': -2.4},
#  {'game_id': 54341,
#   'month': '04',
#   'away_team': 'COL',
#   'away_team_score': 0,
#   'away_team_moneyline': 242,
#   'home_team': 'SF',
#   'home_team_score': 3,
#   'home_team_moneyline': -281,
#   'spread': 3.9},
#  {'game_id': 54345,
#   'month': '04',
#   'away_team': 'LAA',
#   'away_team_score': 3,
#   'away_team_moneyline': -208,
#   'home_team': 'CHC',
#   'home_team_score': 13,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 54346,
#   'month': '04',
#   'away_team': 'CHW',
#   'away_team_score': 14,
#   'away_team_moneyline': -184,
#   'home_team': 'NYY',
#   'home_team_score': 15,
#   'home_team_moneyline': -168,
#   'spread': -2.4},
#  {'game_id': 54347,
#   'month': '04',
#   'away_team': 'PIT',
#   'away_team_score': 15,
#   'away_team_moneyline': -192,
#   'home_team': 'WSH',
#   'home_team_score': 8,
#   'home_team_moneyline': 160,
#   'spread': -2.4},
#  {'game_id': 54348,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 18,
#   'away_team_moneyline': 176,
#   'home_team': 'TOR',
#   'home_team_score': 11,
#   'home_team_moneyline': -208,
#   'spread': 3.9},
#  {'game_id': 54349,
#   'month': '04',
#   'away_team': 'BAL',
#   'away_team_score': 10,
#   'away_team_moneyline': 184,
#   'home_team': 'BOS',
#   'home_team_score': 15,
#   'home_team_moneyline': -216,
#   'spread': -2.4},
#  {'game_id': 54350,
#   'month': '04',
#   'away_team': 'PHI',
#   'away_team_score': 14,
#   'away_team_moneyline': -176,
#   'home_team': 'MIA',
#   'home_team_score': 3,
#   'home_team_moneyline': -176,
#   'spread': 3.9},
#  {'game_id': 54351,
#   'month': '04',
#   'away_team': 'NYM',
#   'away_team_score': 15,
#   'away_team_moneyline': -337,
#   'home_team': 'ATL',
#   'home_team_score': 5,
#   'home_team_moneyline': 282,
#   'spread': -2.4},
#  {'game_id': 54343,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': 13,
#   'away_team_moneyline': 208,
#   'home_team': 'TEX',
#   'home_team_score': 15,
#   'home_team_moneyline': -240,
#   'spread': 3.9},
#  {'game_id': 54352,
#   'month': '04',
#   'away_team': 'DET',
#   'away_team_score': None,
#   'away_team_moneyline': None,
#   'home_team': 'MIN',
#   'home_team_score': None,
#   'home_team_moneyline': None,
#   'spread': None},
#  {'game_id': 54342,
#   'month': '04',
#   'away_team': 'CLE',
#   'away_team_score': 3,
#   'away_team_moneyline': -165,
#   'home_team': 'KC',
#   'home_team_score': 13,
#   'home_team_moneyline': -188,
#   'spread': 3.9},
#  {'game_id': 54353,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 5,
#   'away_team_moneyline': 216,
#   'home_team': 'ARI',
#   'home_team_score': 3,
#   'home_team_moneyline': -248,
#   'spread': 3.9},
#  {'game_id': 54344,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 13,
#   'away_team_moneyline': -248,
#   'home_team': 'LAD',
#   'home_team_score': 13,
#   'home_team_moneyline': 216,
#   'spread': -2.4},
#  {'game_id': 54354,
#   'month': '04',
#   'away_team': 'HOU',
#   'away_team_score': 16,
#   'away_team_moneyline': 184,
#   'home_team': 'SEA',
#   'home_team_score': 15,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 54355,
#   'month': '04',
#   'away_team': 'COL',
#   'away_team_score': 5,
#   'away_team_moneyline': -268,
#   'home_team': 'SF',
#   'home_team_score': 8,
#   'home_team_moneyline': 234,
#   'spread': -2.4},
#  {'game_id': 54363,
#   'month': '04',
#   'away_team': 'BAL',
#   'away_team_score': 14,
#   'away_team_moneyline': 184,
#   'home_team': 'BOS',
#   'home_team_score': 13,
#   'home_team_moneyline': -216,
#   'spread': -2.4},
#  {'game_id': 54358,
#   'month': '04',
#   'away_team': 'CHW',
#   'away_team_score': 0,
#   'away_team_moneyline': -216,
#   'home_team': 'NYY',
#   'home_team_score': 10,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54357,
#   'month': '04',
#   'away_team': 'DET',
#   'away_team_score': 8,
#   'away_team_moneyline': -184,
#   'home_team': 'MIN',
#   'home_team_score': 10,
#   'home_team_moneyline': -168,
#   'spread': -2.4},
#  {'game_id': 54360,
#   'month': '04',
#   'away_team': 'LAA',
#   'away_team_score': 15,
#   'away_team_moneyline': -176,
#   'home_team': 'CHC',
#   'home_team_score': 13,
#   'home_team_moneyline': -176,
#   'spread': -2.4},
#  {'game_id': 54364,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 3,
#   'away_team_moneyline': -216,
#   'home_team': 'TOR',
#   'home_team_score': 8,
#   'home_team_moneyline': 184,
#   'spread': 3.9},
#  {'game_id': 54362,
#   'month': '04',
#   'away_team': 'COL',
#   'away_team_score': 5,
#   'away_team_moneyline': -329,
#   'home_team': 'SF',
#   'home_team_score': 13,
#   'home_team_moneyline': 276,
#   'spread': -2.4},
#  {'game_id': 54365,
#   'month': '04',
#   'away_team': 'PIT',
#   'away_team_score': 5,
#   'away_team_moneyline': -313,
#   'home_team': 'WSH',
#   'home_team_score': 8,
#   'home_team_moneyline': 266,
#   'spread': -2.4},
#  {'game_id': 54366,
#   'month': '04',
#   'away_team': 'PHI',
#   'away_team_score': 8,
#   'away_team_moneyline': -168,
#   'home_team': 'MIA',
#   'home_team_score': 16,
#   'home_team_moneyline': -184,
#   'spread': 3.9},
#  {'game_id': 54367,
#   'month': '04',
#   'away_team': 'STL',
#   'away_team_score': 5,
#   'away_team_moneyline': 216,
#   'home_team': 'CIN',
#   'home_team_score': 13,
#   'home_team_moneyline': -248,
#   'spread': 3.9},
#  {'game_id': 54356,
#   'month': '04',
#   'away_team': 'CLE',
#   'away_team_score': 0,
#   'away_team_moneyline': 231,
#   'home_team': 'KC',
#   'home_team_score': 8,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 54368,
#   'month': '04',
#   'away_team': 'NYM',
#   'away_team_score': 11,
#   'away_team_moneyline': -216,
#   'home_team': 'ATL',
#   'home_team_score': 18,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 54359,
#   'month': '04',
#   'away_team': 'OAK',
#   'away_team_score': None,
#   'away_team_moneyline': 231,
#   'home_team': 'TEX',
#   'home_team_score': None,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 54369,
#   'month': '04',
#   'away_team': 'SD',
#   'away_team_score': 13,
#   'away_team_moneyline': -337,
#   'home_team': 'ARI',
#   'home_team_score': 10,
#   'home_team_moneyline': 282,
#   'spread': -2.4},
#  {'game_id': 54361,
#   'month': '04',
#   'away_team': 'MIL',
#   'away_team_score': 10,
#   'away_team_moneyline': -256,
#   'home_team': 'LAD',
#   'home_team_score': 3,
#   'home_team_moneyline': 224,
#   'spread': -2.4},
#  {'game_id': 54370,
#   'month': '04',
#   'away_team': 'HOU',
#   'away_team_score': 8,
#   'away_team_moneyline': -210,
#   'home_team': 'SEA',
#   'home_team_score': 3,
#   'home_team_moneyline': 178,
#   'spread': 3.9},
#  {'game_id': 54375,
#   'month': '04',
#   'away_team': 'BAL',
#   'away_team_score': 0,
#   'away_team_moneyline': 176,
#   'home_team': 'BOS',
#   'home_team_score': 10,
#   'home_team_moneyline': -208,
#   'spread': -2.4},
#  {'game_id': 54372,
#   'month': '04',
#   'away_team': 'CHW',
#   'away_team_score': 13,
#   'away_team_moneyline': -192,
#   'home_team': 'NYY',
#   'home_team_score': 5,
#   'home_team_moneyline': 160,
#   'spread': -2.4},
#  {'game_id': 54376,
#   'month': '04',
#   'away_team': 'TB',
#   'away_team_score': 13,
#   'away_team_moneyline': 184,
#   'home_team': 'TOR',
#   'home_team_score': 10,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 54377,
#   'month': '04',
#   'away_team': 'PHI',
#   'away_team_score': 8,
#   'away_team_moneyline': 160,
#   'home_team': 'MIA',
#   'home_team_score': 3,
#   'home_team_moneyline': -192,
#   'spread': 3.9},
#  {'game_id': 54379,
#   'month': '04',
#   'away_team': 'PIT',
#   'away_team_score': 10,
#   'away_team_moneyline': -228,
#   'home_team': 'WSH',
#   'home_team_score': 8,
#   'home_team_moneyline': 196,
#   'spread': -2.4},
#  {'game_id': 54380,
#   'month': '04',
#   'away_team': 'DET',
#   'away_team_score': 10,
#   'away_team_moneyline': -165,
#   'home_team': 'MIN',
#   'home_team_score': 15,
# ...
#   'home_team_moneyline': -176,
#   'spread': 3.9},
#  {'game_id': 55063,
#   'month': '06',
#   'away_team': 'CHW',
#   'away_team_score': 10,
#   'away_team_moneyline': -181,
#   'home_team': 'WSH',
#   'home_team_score': 15,
#   'home_team_moneyline': 164,
#   'spread': -2.4},
#  {'game_id': 55065,
#   'month': '06',
#   'away_team': 'LAD',
#   'away_team_score': 5,
#   'away_team_moneyline': -170,
#   'home_team': 'ARI',
#   'home_team_score': 8,
#   'home_team_moneyline': -167,
#   'spread': 3.9},
#  {'game_id': 55064,
#   'month': '06',
#   'away_team': 'PHI',
#   'away_team_score': 11,
#   'away_team_moneyline': 231,
#   'home_team': 'SD',
#   'home_team_score': 13,
#   'home_team_moneyline': -264,
#   'spread': 3.9},
#  {'game_id': 55066,
#   'month': '06',
#   'away_team': 'ATL',
#   'away_team_score': 10,
#   'away_team_moneyline': 199,
#   'home_team': 'PIT',
#   'home_team_score': 11,
#   'home_team_moneyline': -220,
#   'spread': 3.9},
#  {'game_id': 55067,
#   'month': '06',
#   'away_team': 'NYY',
#   'away_team_score': 11,
#   'away_team_moneyline': -216,
#   'home_team': 'TOR',
#   'home_team_score': 18,
#   'home_team_moneyline': 184,
#   'spread': 3.9},
#  {'game_id': 55060,
#   'month': '06',
#   'away_team': 'MIN',
#   'away_team_score': 11,
#   'away_team_moneyline': 210,
#   'home_team': 'CLE',
#   'home_team_score': 14,
#   'home_team_moneyline': -242,
#   'spread': 3.9},
#  {'game_id': 55068,
#   'month': '06',
#   'away_team': 'TB',
#   'away_team_score': 10,
#   'away_team_moneyline': -204,
#   'home_team': 'DET',
#   'home_team_score': 0,
#   'home_team_moneyline': 172,
#   'spread': 3.9},
#  {'game_id': 55069,
#   'month': '06',
#   'away_team': 'SF',
#   'away_team_score': 0,
#   'away_team_moneyline': -224,
#   'home_team': 'NYM',
#   'home_team_score': 11,
#   'home_team_moneyline': 204,
#   'spread': -2.4},
#  {'game_id': 55070,
#   'month': '06',
#   'away_team': 'MIA',
#   'away_team_score': 13,
#   'away_team_moneyline': 176,
#   'home_team': 'MIL',
#   'home_team_score': 8,
#   'home_team_moneyline': -208,
#   'spread': -2.4},
#  {'game_id': 55071,
#   'month': '06',
#   'away_team': 'COL',
#   'away_team_score': 13,
#   'away_team_moneyline': -321,
#   'home_team': 'CHC',
#   'home_team_score': 14,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 55062,
#   'month': '06',
#   'away_team': 'BAL',
#   'away_team_score': 3,
#   'away_team_moneyline': -216,
#   'home_team': 'TEX',
#   'home_team_score': 5,
#   'home_team_moneyline': 184,
#   'spread': -2.4},
#  {'game_id': 55061,
#   'month': '06',
#   'away_team': 'BOS',
#   'away_team_score': 13,
#   'away_team_moneyline': -240,
#   'home_team': 'KC',
#   'home_team_score': 0,
#   'home_team_moneyline': 208,
#   'spread': 3.9},
#  {'game_id': 55072,
#   'month': '06',
#   'away_team': 'CIN',
#   'away_team_score': None,
#   'away_team_moneyline': -237,
#   'home_team': 'STL',
#   'home_team_score': None,
#   'home_team_moneyline': 205,
#   'spread': -2.4},
#  {'game_id': 55073,
#   'month': '06',
#   'away_team': 'OAK',
#   'away_team_score': 14,
#   'away_team_moneyline': -276,
#   'home_team': 'LAA',
#   'home_team_score': 16,
#   'home_team_moneyline': 239,
#   'spread': -2.4},
#  {'game_id': 55074,
#   'month': '06',
#   'away_team': 'HOU',
#   'away_team_score': 3,
#   'away_team_moneyline': -164,
#   'home_team': 'SEA',
#   'home_team_score': 22,
#   'home_team_moneyline': -173,
#   'spread': 3.9},
#  {'game_id': 55078,
#   'month': '06',
#   'away_team': 'SF',
#   'away_team_score': 8,
#   'away_team_moneyline': -224,
#   'home_team': 'NYM',
#   'home_team_score': 11,
#   'home_team_moneyline': 192,
#   'spread': -2.4},
#  {'game_id': 55079,
#   'month': '06',
#   'away_team': 'ATL',
#   'away_team_score': 3,
#   'away_team_moneyline': 224,
#   'home_team': 'PIT',
#   'home_team_score': 15,
#   'home_team_moneyline': -258,
#   'spread': 3.9},
#  {'game_id': 55080,
#   'month': '06',
#   'away_team': 'TB',
#   'away_team_score': 15,
#   'away_team_moneyline': -200,
#   'home_team': 'DET',
#   'home_team_score': 3,
#   'home_team_moneyline': 168,
#   'spread': 3.9},
#  {'game_id': 55076,
#   'month': '06',
#   'away_team': 'BOS',
#   'away_team_score': 11,
#   'away_team_moneyline': 184,
#   'home_team': 'KC',
#   'home_team_score': 13,
#   'home_team_moneyline': -216,
#   'spread': 3.9},
#  {'game_id': 55081,
#   'month': '06',
#   'away_team': 'CIN',
#   'away_team_score': 3,
#   'away_team_moneyline': -240,
#   'home_team': 'STL',
#   'home_team_score': 8,
#   'home_team_moneyline': 208,
#   'spread': -2.4},
#  {'game_id': 55082,
#   'month': '06',
#   'away_team': 'MIA',
#   'away_team_score': 3,
#   'away_team_moneyline': -208,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 55083,
#   'month': '06',
#   'away_team': 'COL',
#   'away_team_score': 8,
#   'away_team_moneyline': None,
#   'home_team': 'CHC',
#   'home_team_score': 3,
#   'home_team_moneyline': None,
#   'spread': None},
#  {'game_id': 55084,
#   'month': '06',
#   'away_team': 'HOU',
#   'away_team_score': 13,
#   'away_team_moneyline': -204,
#   'home_team': 'SEA',
#   'home_team_score': 11,
#   'home_team_moneyline': 172,
#   'spread': 3.9},
#  {'game_id': 55085,
#   'month': '06',
#   'away_team': 'NYY',
#   'away_team_score': 15,
#   'away_team_moneyline': -236,
#   'home_team': 'TOR',
#   'home_team_score': 5,
#   'home_team_moneyline': 204,
#   'spread': 3.9},
#  {'game_id': 55075,
#   'month': '06',
#   'away_team': 'MIN',
#   'away_team_score': 13,
#   'away_team_moneyline': -345,
#   'home_team': 'CLE',
#   'home_team_score': 10,
#   'home_team_moneyline': 289,
#   'spread': -2.4},
#  {'game_id': 55077,
#   'month': '06',
#   'away_team': 'BAL',
#   'away_team_score': 8,
#   'away_team_moneyline': -168,
#   'home_team': 'TEX',
#   'home_team_score': 10,
#   'home_team_moneyline': -184,
#   'spread': -2.4},
#  {'game_id': 55086,
#   'month': '06',
#   'away_team': 'OAK',
#   'away_team_score': 11,
#   'away_team_moneyline': -289,
#   'home_team': 'LAA',
#   'home_team_score': 10,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 55087,
#   'month': '06',
#   'away_team': 'WSH',
#   'away_team_score': 10,
#   'away_team_moneyline': -353,
#   'home_team': 'SD',
#   'home_team_score': 13,
#   'home_team_moneyline': 293,
#   'spread': -2.4},
#  {'game_id': 55092,
#   'month': '06',
#   'away_team': 'STL',
#   'away_team_score': 3,
#   'away_team_moneyline': -305,
#   'home_team': 'CHC',
#   'home_team_score': 8,
#   'home_team_moneyline': 261,
#   'spread': -2.4},
#  {'game_id': 55093,
#   'month': '06',
#   'away_team': 'CIN',
#   'away_team_score': 5,
#   'away_team_moneyline': -276,
#   'home_team': 'PHI',
#   'home_team_score': 10,
#   'home_team_moneyline': 248,
#   'spread': -2.4},
#  {'game_id': 55094,
#   'month': '06',
#   'away_team': 'ARI',
#   'away_team_score': 13,
#   'away_team_moneyline': -268,
#   'home_team': 'TOR',
#   'home_team_score': 5,
#   'home_team_moneyline': 242,
#   'spread': -2.4},
#  {'game_id': 55095,
#   'month': '06',
#   'away_team': 'TB',
#   'away_team_score': 13,
#   'away_team_moneyline': -301,
#   'home_team': 'BOS',
#   'home_team_score': 3,
#   'home_team_moneyline': 271,
#   'spread': -2.4},
#  {'game_id': 55088,
#   'month': '06',
#   'away_team': 'NYY',
#   'away_team_score': 5,
#   'away_team_moneyline': 218,
#   'home_team': 'CLE',
#   'home_team_score': 13,
#   'home_team_moneyline': -250,
#   'spread': 3.9},
#  {'game_id': 55096,
#   'month': '06',
#   'away_team': 'MIN',
#   'away_team_score': 15,
#   'away_team_moneyline': 200,
#   'home_team': 'DET',
#   'home_team_score': 8,
#   'home_team_moneyline': -232,
#   'spread': 3.9},
#  {'game_id': 55098,
#   'month': '06',
#   'away_team': 'ATL',
#   'away_team_score': 11,
#   'away_team_moneyline': -194,
#   'home_team': 'MIA',
#   'home_team_score': 3,
#   'home_team_moneyline': 162,
#   'spread': 3.9},
#  {'game_id': 55097,
#   'month': '06',
#   'away_team': 'COL',
#   'away_team_score': 13,
#   'away_team_moneyline': -189,
#   'home_team': 'NYM',
#   'home_team_score': 3,
#   'home_team_moneyline': 160,
#   'spread': -2.4},
#  {'game_id': 55090,
#   'month': '06',
#   'away_team': 'OAK',
#   'away_team_score': 13,
#   'away_team_moneyline': -303,
#   'home_team': 'TEX',
#   'home_team_score': 8,
#   'home_team_moneyline': 273,
#   'spread': -2.4},
#  {'game_id': 55091,
#   'month': '06',
#   'away_team': 'BAL',
#   'away_team_score': 8,
#   'away_team_moneyline': 232,
#   'home_team': 'HOU',
#   'home_team_score': 10,
#   'home_team_moneyline': -258,
#   'spread': -2.4},
#  {'game_id': 55099,
#   'month': '06',
#   'away_team': 'PIT',
#   'away_team_score': 10,
#   'away_team_moneyline': 192,
#   'home_team': 'MIL',
#   'home_team_score': 16,
#   'home_team_moneyline': -224,
#   'spread': -2.4},
#  {'game_id': 55089,
#   'month': '06',
#   'away_team': 'CHW',
#   'away_team_score': 10,
#   'away_team_moneyline': -289,
#   'home_team': 'KC',
#   'home_team_score': 15,
#   'home_team_moneyline': 260,
#   'spread': -2.4},
#  {'game_id': 55100,
#   'month': '06',
#   'away_team': 'SEA',
#   'away_team_score': 15,
#   'away_team_moneyline': -197,
#   'home_team': 'LAA',
#   'home_team_score': 5,
#   'home_team_moneyline': 178,
#   'spread': -2.4},
#  {'game_id': 55101,
#   'month': '06',
#   'away_team': 'WSH',
#   'away_team_score': 10,
#   'away_team_moneyline': 218,
#   'home_team': 'SD',
#   'home_team_score': 13,
#   'home_team_moneyline': -250,
#   'spread': 3.9},
#  {'game_id': 55102,
#   'month': '06',
#   'away_team': 'LAD',
#   'away_team_score': 3,
#   'away_team_moneyline': -255,
#   'home_team': 'SF',
#   'home_team_score': 5,
#   'home_team_moneyline': 221,
#   'spread': 3.9},
#  {'game_id': 55108,
#   'month': '06',
#   'away_team': 'TB',
#   'away_team_score': 14,
#   'away_team_moneyline': 208,
#   'home_team': 'BOS',
#   'home_team_score': 5,
#   'home_team_moneyline': -229,
#   'spread': 3.9},
#  {'game_id': 56598,
#   'month': '06',
#   'away_team': 'OAK',
#   'away_team_score': 13,
#   'away_team_moneyline': 175,
#   'home_team': 'TEX',
#   'home_team_score': 16,
#   'home_team_moneyline': -207,
#   'spread': 3.9},
#  {'game_id': 55104,
#   'month': '06',
#   'away_team': 'CHW',
#   'away_team_score': 5,
#   'away_team_moneyline': -168,
#   'home_team': 'KC',
#   'home_team_score': 0,
#   'home_team_moneyline': -184,
#   'spread': 3.9},
#  {'game_id': 55109,
#   'month': '06',
#   'away_team': 'ARI',
#   'away_team_score': 15,
#   'away_team_moneyline': 210,
#   'home_team': 'TOR',
#   'home_team_score': 0,
#   'home_team_moneyline': -242,
#   'spread': 3.9},
#  {'game_id': 55110,
#   'month': '06',
#   'away_team': 'CIN',
#   'away_team_score': 3,
#   'away_team_moneyline': -273,
#   'home_team': 'PHI',
#   'home_team_score': 10,
#   'home_team_moneyline': 237,
#   'spread': -2.4},
#  {'game_id': 55103,
#   'month': '06',
#   'away_team': 'NYY',
#   'away_team_score': 10,
#   'away_team_moneyline': 191,
#   'home_team': 'CLE',
#   'home_team_score': 13,
#   'home_team_moneyline': -223,
#   'spread': 3.9},
#  {'game_id': 55111,
#   'month': '06',
#   'away_team': 'MIN',
#   'away_team_score': 8,
#   'away_team_moneyline': -248,
#   'home_team': 'DET',
#   'home_team_score': 14,
#   'home_team_moneyline': 216,
#   'spread': 3.9},
#  {'game_id': 55106,
#   'month': '06',
#   'away_team': 'BAL',
#   'away_team_score': 10,
#   'away_team_moneyline': 168,
#   'home_team': 'HOU',
#   'home_team_score': 3,
#   'home_team_moneyline': -200,
#   'spread': -2.4},
#  {'game_id': 55113,
#   'month': '06',
#   'away_team': 'ATL',
#   'away_team_score': 3,
#   'away_team_moneyline': 168,
#   'home_team': 'MIA',
#   'home_team_score': 0,
#   'home_team_moneyline': -200,
#   'spread': 3.9},
#  {'game_id': 55112,
#   'month': '06',
#   'away_team': 'PIT',
#   'away_team_score': 8,
#   'away_team_moneyline': -224,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': 192,
#   'spread': -2.4},
#  {'game_id': 56604,
#   'month': '06',
#   'away_team': 'TB',
#   'away_team_score': 3,
#   'away_team_moneyline': -231,
#   'home_team': 'BOS',
#   'home_team_score': 13,
#   'home_team_moneyline': 197,
#   'spread': -2.4},
#  {'game_id': 55114,
#   'month': '06',
#   'away_team': 'STL',
#   'away_team_score': 10,
#   'away_team_moneyline': 229,
#   'home_team': 'CHC',
#   'home_team_score': 14,
#   'home_team_moneyline': -263,
#   'spread': 3.9},
#  {'game_id': 55115,
#   'month': '06',
#   'away_team': 'COL',
#   'away_team_score': 8,
#   'away_team_moneyline': -337,
#   'home_team': 'NYM',
#   'home_team_score': 13,
#   'home_team_moneyline': 282,
#   'spread': -2.4},
#  {'game_id': 55116,
#   'month': '06',
#   'away_team': 'LAD',
#   'away_team_score': 11,
#   'away_team_moneyline': -216,
#   'home_team': 'SF',
#   'home_team_score': 5,
#   'home_team_moneyline': 186,
#   'spread': 3.9},
#  {'game_id': 55105,
#   'month': '06',
#   'away_team': 'OAK',
#   'away_team_score': 3,
#   'away_team_moneyline': -172,
#   'home_team': 'TEX',
#   'home_team_score': 8,
#   'home_team_moneyline': -181,
#   'spread': 3.9},
#  {'game_id': 55117,
#   'month': '06',
#   'away_team': 'SEA',
#   'away_team_score': 8,
#   'away_team_moneyline': -276,
#   'home_team': 'LAA',
#   'home_team_score': 19,
#   'home_team_moneyline': 239,
#   'spread': -2.4},
#  {'game_id': 55107,
#   'month': '06',
#   'away_team': 'WSH',
#   'away_team_score': 10,
#   'away_team_moneyline': -181,
#   'home_team': 'SD',
#   'home_team_score': 3,
#   'home_team_moneyline': -172,
#   'spread': 3.9},
#  {'game_id': 55122,
#   'month': '06',
#   'away_team': 'TB',
#   'away_team_score': 15,
#   'away_team_moneyline': 199,
#   'home_team': 'BOS',
#   'home_team_score': 3,
#   'home_team_moneyline': -231,
#   'spread': 3.9},
#  {'game_id': 55123,
#   'month': '06',
#   'away_team': 'CIN',
#   'away_team_score': 10,
#   'away_team_moneyline': -274,
#   'home_team': 'PHI',
#   'home_team_score': 8,
#   'home_team_moneyline': 239,
#   'spread': -2.4},
#  {'game_id': 55124,
#   'month': '06',
#   'away_team': 'ARI',
#   'away_team_score': 13,
#   'away_team_moneyline': 180,
#   'home_team': 'TOR',
#   'home_team_score': 5,
#   'home_team_moneyline': -210,
#   'spread': 3.9},
#  {'game_id': 55118,
#   'month': '06',
#   'away_team': 'NYY',
#   'away_team_score': 11,
#   'away_team_moneyline': -256,
#   'home_team': 'CLE',
#   'home_team_score': 15,
#   'home_team_moneyline': 224,
#   'spread': -2.4},
#  {'game_id': 55125,
#   'month': '06',
#   'away_team': 'MIN',
#   'away_team_score': 19,
#   'away_team_moneyline': -216,
#   'home_team': 'DET',
#   'home_team_score': 5,
#   'home_team_moneyline': 189,
#   'spread': 3.9},
#  {'game_id': 55127,
#   'month': '06',
#   'away_team': 'ATL',
#   'away_team_score': 11,
#   'away_team_moneyline': 191,
#   'home_team': 'MIA',
#   'home_team_score': 15,
#   'home_team_moneyline': -223,
#   'spread': 3.9},
#  {'game_id': 55126,
#   'month': '06',
#   'away_team': 'COL',
#   'away_team_score': 3,
#   'away_team_moneyline': -224,
#   'home_team': 'NYM',
#   'home_team_score': 15,
#   'home_team_moneyline': 204,
#   'spread': -2.4},
#  {'game_id': 55121,
#   'month': '06',
#   'away_team': 'BAL',
#   'away_team_score': 0,
#   'away_team_moneyline': -184,
#   'home_team': 'HOU',
#   'home_team_score': 10,
#   'home_team_moneyline': -168,
#   'spread': -2.4},
#  {'game_id': 55128,
#   'month': '06',
#   'away_team': 'PIT',
#   'away_team_score': 5,
#   'away_team_moneyline': -191,
#   'home_team': 'MIL',
#   'home_team_score': 13,
#   'home_team_moneyline': -162,
#   'spread': -2.4},
#  {'game_id': 55119,
#   'month': '06',
#   'away_team': 'CHW',
#   'away_team_score': 13,
#   'away_team_moneyline': -253,
#   'home_team': 'KC',
#   'home_team_score': 5,
#   'home_team_moneyline': 221,
#   'spread': -2.4},
#  {'game_id': 55120,
#   'month': '06',
#   'away_team': 'OAK',
#   'away_team_score': 14,
#   'away_team_moneyline': -234,
#   'home_team': 'TEX',
#   'home_team_score': 13,
#   'home_team_moneyline': 202,
#   'spread': 3.9},
#  {'game_id': 55130,
#   'month': '06',
#   'away_team': 'LAD',
#   'away_team_score': 3,
#   'away_team_moneyline': 160,
#   'home_team': 'SF',
#   'home_team_score': 0,
#   'home_team_moneyline': -192,
#   'spread': 3.9},
#  {'game_id': 55131,
#   'month': '06',
#   'away_team': 'SEA',
#   'away_team_score': 14,
#   'away_team_moneyline': -224,
#   'home_team': 'LAA',
#   'home_team_score': 8,
#   'home_team_moneyline': 192,
#   'spread': -2.4},
#  {'game_id': 55132,
#   'month': '06',
#   'away_team': 'WSH',
#   'away_team_score': 13,
#   'away_team_moneyline': 167,
#   'home_team': 'SD',
#   'home_team_score': 5,
#   'home_team_moneyline': -199,
#   'spread': 3.9},
#  {'game_id': 55129,
#   'month': '06',
#   'away_team': 'STL',
#   'away_team_score': 3,
#   'away_team_moneyline': -210,
#   'home_team': 'CHC',
#   'home_team_score': 13,
#   'home_team_moneyline': 176,
#   'spread': -2.4},
#  {'game_id': 55135,
#   'month': '06',
#   'away_team': 'NYM',
#   'away_team_score': None,
#   'away_team_moneyline': -200,
#   'home_team': 'NYY',
#   'home_team_score': None,
#   'home_team_moneyline': 168,
#   'spread': -2.4},
#  ...]

# %% [markdown]
# ## Inserting to table

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = 'sports'
)
cursor = cnx.cursor(buffered=True)

# %%
# cursor.execute("""
# CREATE DATABASE MLB
# """)

# cursor.close()
# cnx.close()

# %%
cursor.execute("""
    CREATE TABLE MLB_2019_GAMES (
    game_id varchar(11) NOT NULL primary key,
    month varchar(2) not null,
    away_team varchar(11) not null,
    away_team_score int(3) not null,
    home_team varchar(11) not null,
    home_team_score int(3) not null,
    away_team_moneyline int(4) not null,
    home_team_moneyline int(4) not null,
    spread float(5) not null
    )
""")

# %%
mlb_games_to_insert = []

for game in parsed_games_mlb:

    mlb_game_to_insert = (
        game['game_id'], 
        game['month'], 
        game['away_team'],
        game['away_team_score'],
        game['home_team'], 
        game['home_team_score'],
        game['away_team_moneyline'],
        game['home_team_moneyline'],
        game['spread'] 
    )
    
    mlb_games_to_insert.append(mlb_game_to_insert)

# %%
insert_query = """
    INSERT INTO MLB_2019_GAMES (
            game_id,
            month,
            away_team,
            away_team_score,
            home_team,
            home_team_score,
            away_team_moneyline,
            home_team_moneyline,
            spread
        )
    VALUES (
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s
        )
"""
cursor.executemany(insert_query, mlb_games_to_insert)
cnx.commit()

# %% [markdown]
# ### Questions (Null Hypothesis)

# %% [markdown]
# Is there a "home field" advantage(in general , 2018 season)?
#
# Will a home team preform better (by month)?
#
# If home team cover more than away team ("good teams win, great teams cover")?

# %% [markdown]
# ## Creating MLB DataFrame

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = 'sports'
)
cursor = cnx.cursor(buffered=True)

# %%
cursor.execute(  """SELECT * FROM MLB_2019_GAMES
                    order by game_id;""")
#assigning database (pointed in MySql) as a dataframe using pandas                         
df_mlb = pd.DataFrame(cursor.fetchall())


#assigning the column names 
df_mlb.columns=['game_id','month', 'away_team', 'away_team_score', 'home_team', 'home_team_score', 'away_team_moneyline', 'home_team_moneyline', 'spread']

# %%
df_mlb
# Out:
#      game_id month away_team  away_team_score home_team  home_team_score  \
# 0      54052    03       SEA               14       OAK               11
# 1      54066    03       SEA               13       OAK               10
# 2      54152    03       CHW                8        KC               13
# 3      54153    03       CHC               19       TEX               10
# 4      54154    03       HOU               13        TB                3
# 5      54155    03       BAL                5       NYY               11
# 6      54156    03       NYM                5       WSH                0
# 7      54157    03       STL               10       MIL               13
# 8      54158    03       ATL               10       PHI               16
# 9      54159    03       DET                5       TOR                0
# 10     54160    03       ARI               13       LAD               19
# 11     54161    03       LAA                0       OAK               10
# 12     54162    03       CLE                0       MIN                5
# 13     54163    03       PIT                8       CIN               13
# 14     54164    03        SF                0        SD                5
# 15     54165    03       COL               15       MIA                8
# 16     54166    03       BOS               10       SEA               19
# 17     54167    03       ARI               13       LAD               10
# 18     54168    03       HOU                5        TB               10
# 19     54169    03       DET                0       TOR               15
# 20     54170    03       COL               15       MIA                3
# 21     54171    03       STL               14       MIL               13
# 22     54172    03       LAA               15       OAK                5
# 23     54173    03       BOS               11       SEA               15
# 24     54174    03        SF                3        SD               10
# 25     54175    03       CHW               15        KC               13
# 26     54176    03       CLE                5       MIN                3
# 27     54177    03       BAL               13       NYY                8
# 28     54178    03       CHC               15       TEX               13
# 29     54179    03       ARI               13       LAD               29
# ...      ...   ...       ...              ...       ...              ...
# 2438   56601    04       ATL               13       CLE               11
# 2439   56602    08       CHW               13       DET                8
# 2440   56603    04       DET               11       BOS               10
# 2441   56604    06        TB                3       BOS               13
# 2442   56605    07       DET               13       CHW               11
# 2443   56606    05        TB                5        KC               13
# 2444   56607    05       BAL               15       CHW               11
# 2445   56608    07        TB                3       BAL                5
# 2446   56609    07        SF               30       COL                5
# 2447   56610    08       MIA                5       NYM               15
# 2448   56611    05       BAL                8       NYY               13
# 2449   56612    08       BAL               13       NYY               13
# 2450   56613    05        KC                8       STL               16
# 2451   56614    05       MIN               26       LAA               11
# 2452   56615    05       NYY               15        KC               13
# 2453   56616    08       BOS               10       NYY               15
# 2454   56617    08       CIN               15       STL               16
# 2455   56618    06       NYM               13       NYY               19
# 2456   56619    06       PHI                5       WSH               15
# 2457   56620    09       PHI                3       WSH               10
# 2458   56621    09       DET                0       CHW                0
# 2459   56622    08       LAA               13       TEX                3
# 2460   56623    07        TB                5       NYY               15
# 2461   56624    07       COL                5       WSH                8
# 2462   56625    08       TEX                3       CLE               13
# 2463   56626    08       HOU               15       CHW                5
# 2464   56627    09       CIN               13       STL                8
# 2465   56628    09       NYY               15       DET               10
# 2466   56629    09       MIN                5       CLE                0
# 2467   56630    09       DET               10       CHW                8
#
#       away_team_moneyline  home_team_moneyline  spread
# 0                    -263                  237    -2.4
# 1                    -372                  332    -2.4
# 2                    -306                  274    -2.4
# 3                     205                 -240     3.9
# 4                     213                 -260     3.9
# 5                     258                 -301    -2.4
# 6                    -330                  295    -2.4
# 7                    -305                  274    -2.4
# 8                    -208                  176    -2.4
# 9                    -244                  213    -2.4
# 10                   -252                  216    -2.4
# 11                   -353                  298    -2.4
# 12                    273                 -321     3.9
# 13                   -329                  281    -2.4
# 14                   -298                  248    -2.4
# 15                    197                 -226     3.9
# 16                   -188                  164     3.9
# 17                   -232                  200    -2.4
# 18                    188                 -220     3.9
# 19                   -289                  248    -2.4
# 20                    168                 -202     3.9
# 21                    237                 -273     3.9
# 22                    242                 -281     3.9
# 23                    184                 -216     3.9
# 24                   -244                  212    -2.4
# 25                   -279                  252    -2.4
# 26                   -393                  349    -2.4
# 27                    232                 -268    -2.4
# 28                    162                 -178     3.9
# 29                   -183                  167    -2.4
# ...                   ...                  ...     ...
# 2438                 -237                  215    -2.4
# 2439                 -321                  273    -2.4
# 2440                 -199                  170    -2.4
# 2441                 -231                  197    -2.4
# 2442                 -231                  196    -2.4
# 2443                 -224                  204     3.9
# 2444                 -256                  224    -2.4
# 2445                 -240                  197     3.9
# 2446                  168                 -200    -2.4
# 2447                  240                 -273    -2.4
# 2448                  181                 -200    -2.4
# 2449                  256                 -289    -2.4
# 2450                 -184                 -168    -2.4
# 2451                  192                 -224     3.9
# 2452                 -176                 -176     3.9
# 2453                 -232                  200    -2.4
# 2454                 -273                  240    -2.4
# 2455                 -188                 -175    -1.6
# 2456                 -244                  208    -2.4
# 2457                 -213                  176    -2.4
# 2458                 -199                  164    -2.4
# 2459                  168                 -200     3.9
# 2460                 -229                  192    -2.4
# 2461                 -289                  256    -2.4
# 2462                  232                 -264    -2.4
# 2463                 -337                  289     3.9
# 2464                  240                 -273     3.9
# 2465                 -289                  256     3.9
# 2466                 -184                 -168    -2.4
# 2467                 -199                  160    -2.4
#
# [2468 rows x 9 columns]
